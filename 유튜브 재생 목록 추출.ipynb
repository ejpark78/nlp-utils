# %%
# %load_ext autoreload
# %autoreload 2

# %%
import re
import json
import requests

# %%
url = 'https://www.youtube.com/watch?v=VnAqVULPcAA&list=PLmF_CDUVuBvj9Ir00ueSMrHNDyDeeVmdq'

headers = {
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.79 Safari/537.36'
}

resp = requests.get(url, headers=headers)

resp.status_code
# Out:
# 200

# %%
from pprint import pprint

for line in resp.text.split('\n'):
    if line.find('"ytInitialData"') < 0:
        continue
        
    line = line.split('=', maxsplit=1)[-1].rsplit(';', maxsplit=1)[0].strip()
    doc = json.loads(line)
    
    print(line)
# Out:
# {"responseContext":{"serviceTrackingParams":[{"service":"GFEEDBACK","params":[{"key":"has_unlimited_entitlement","value":"False"},{"key":"has_unlimited_ncc_free_trial","value":"False"},{"key":"e","value":"23744176,23804281,23809316,23827263,23836248,23837040,23837993,23839597,23842630,23847144,23848795,23851754,23853886,23855886,23856652,23857946,23857998,23859802,23859863,23861041,23861503,23862427,23863880,23865369,23865547,23866661,23866689,23867831,23868333,23868460,23868460,9449243,9471239"},{"key":"logged_in","value":"0"}]},{"service":"GUIDED_HELP","params":[{"key":"context","value":"yt_web_kevlar_watch"},{"key":"logged_in","value":"0"}]},{"service":"CSI","params":[{"key":"GetWatchNext_rid","value":"0x3d22a5c764f9b443"},{"key":"c","value":"WEB"},{"key":"cver","value":"2.20200107.00.01"},{"key":"yt_li","value":"0"}]},{"service":"ECATCHER","params":[{"key":"client.name","value":"WEB"},{"key":"client.version","value":"2.20200104"},{"key":"innertube.build.changelist","value":"288558518"},{"key":"innertube.build.experiments.source_version","value":"288595946"},{"key":"innertube.build.label","value":"youtube.ytfe.innertube_20200103_9_RC2"},{"key":"innertube.build.timestamp","value":"1578432515"},{"key":"innertube.build.variants.checksum","value":"92feb05d42f25e71d9b75bb0b87849d0"},{"key":"innertube.run.job","value":"ytfe-innertube-replica-only.ytfe"}]}],"webResponseContextExtensionData":{"ytConfigData":{"csn":"n1IVXsWhCNCOlQT1_Y2IBA","visitorData":"CgthM2JpWUtqdXBRbyifpdXwBQ%3D%3D","rootVisualElementType":3832},"webPrefetchData":{"navigationEndpoints":[{"clickTrackingParams":"CEYQ0TkiEwjv09XfjfPmAhUG61gKHRFbC7UyCGF1dG9wbGF5SIDgvZbUyoq4Vg==","commandMetadata":{"webCommandMetadata":{"url":"/watch?v=0mecSUibC3E\u0026list=PLmF_CDUVuBvj9Ir00ueSMrHNDyDeeVmdq\u0026index=2","webPageType":"WEB_PAGE_TYPE_WATCH","rootVe":3832}},"watchEndpoint":{"videoId":"0mecSUibC3E","playlistId":"PLmF_CDUVuBvj9Ir00ueSMrHNDyDeeVmdq","index":1,"params":"EAEYATgBYgtWbkFxVlVMUGNBQWgA","watchEndpointSupportedPrefetchConfig":{"prefetchHintConfig":{"prefetchPriority":0,"playbackRelativeSecondsPrefetchCondition":-3}}}},{"clickTrackingParams":"CEYQ0TkiEwjv09XfjfPmAhUG61gKHRFbC7UyCGF1dG9wbGF5SIDgvZbUyoq4Vg==","commandMetadata":{"webCommandMetadata":{"url":"/watch?v=0mecSUibC3E\u0026list=PLmF_CDUVuBvj9Ir00ueSMrHNDyDeeVmdq\u0026index=2","webPageType":"WEB_PAGE_TYPE_WATCH","rootVe":3832}},"watchEndpoint":{"videoId":"0mecSUibC3E","playlistId":"PLmF_CDUVuBvj9Ir00ueSMrHNDyDeeVmdq","index":1,"params":"EAEYAzgBYgtWbkFxVlVMUGNBQWgA","watchEndpointSupportedPrefetchConfig":{"prefetchHintConfig":{"prefetchPriority":0,"playbackRelativeSecondsPrefetchCondition":-3}}}}]}}},"contents":{"twoColumnWatchNextResults":{"results":{"results":{"contents":[{"videoPrimaryInfoRenderer":{"title":{"runs":[{"text":"똘끼 리니지m 리니지2m 죄송합니다 공지론 부족해서 직접 말씀드리려고 켰습니다 잠깐방송 2020.1.3 LIVE"}]},"viewCount":{"videoViewCountRenderer":{"viewCount":{"simpleText":"조회수 39,624회"},"shortViewCount":{"simpleText":"조회수 3.9만회"}}},"videoActions":{"menuRenderer":{"items":[{"menuNavigationItemRenderer":{"text":{"runs":[{"text":"신고"}]},"icon":{"iconType":"FLAG"},"navigationEndpoint":{"clickTrackingParams":"CNYEEMyrARgAIhMI79PV343z5gIVButYCh0RWwu1","commandMetadata":{"webCommandMetadata":{"ignoreNavigation":true}},"modalEndpoint":{"modal":{"modalWithTitleAndButtonRenderer":{"title":{"simpleText":"동영상을 신고하시겠습니까?"},"content":{"runs":[{"text":"부적절한 콘텐츠를 신고하려면 로그인하세요."}]},"button":{"buttonRenderer":{"style":"STYLE_BRAND","size":"SIZE_DEFAULT","isDisabled":false,"text":{"simpleText":"로그인"},"navigationEndpoint":{"clickTrackingParams":"CN8EEPBbIhMI79PV343z5gIVButYCh0RWwu1","commandMetadata":{"webCommandMetadata":{"url":"https://accounts.google.com/ServiceLogin?service=youtube\u0026uilel=3\u0026passive=true\u0026continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253DVnAqVULPcAA%2526list%253DPLmF_CDUVuBvj9Ir00ueSMrHNDyDeeVmdq\u0026hl=ko","rootVe":83769} ...
