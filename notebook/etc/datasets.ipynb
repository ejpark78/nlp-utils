# %%
from nlplab.datasets.confluence_utils import ConfluenceUtils

utils = ConfluenceUtils()

# %%
page_list = utils.get_page_list(state='done')

all_page = utils.get_all_page(page_list=page_list)

utils.save_all_page(
    path='data/confluence',
    page_list=all_page['page_list'],
)

utils.download_all_file(
    path='data/confluence',
    page_list=all_page['page_list'],
)

utils.save_report(
    path='data/confluence',
    page_info=all_page,
)

# %%
attchment = utils.read_attachment(page_id='35692809', path='data/confluence')

# %%
import pprint

pprint.pprint(list(attchment.keys()))

# %%
df = attchment['리니지M_게시판_문장별_감성분류_데이터_5000_20190706(완료)'].fillna('')
df.groupby(by='tag').size().to_frame()

# %%
from nlplab.datasets.contents import DataSetInfo, load_data

info = DataSetInfo()
# Out:
# /home/.local/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:18: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
meta_info = info.get_meta()
meta_info
# Out:
# ...
#                                                        text  \
# pageId
# 14915891                                <양식> 작업 완료서 양식 (샘플)
# 35692809  [TYPE B] (20190628) 리니지M 게시판 문장 감성분류 태그 코퍼스 2차 구축
# 35698014                   [TYPE B] (20190711) 야구 대기록 질문 구축
# 35695238                    [TYPE B] (20190704) 야구 영상 질문 구축
# 35687479        [TYPE B] (20190612) 리니지M 게시판 문장 감성분류 태그 코퍼스
# ...                                                     ...
# 31987397        [TYPE B] (20190122 ~20190131) 생략복원 태깅코퍼스 수정
# 31991785  [TYPE B] (20190212 ~ 20190227) PAIGE 2.0 추가 질문...
# 31985883  [Type B](20190116 ~20190201) 제스처 추천 평가 말뭉치 구축(2차)
# 29396663  [TYPE A] (20181101 ~ 20181108) 주제/화행 체계 및 대화 코...
# 33389353           [TYPE B] (20190527~20190527) 야구공작소 퀴즈 정리
#
#                                    date                      코퍼스명 요청자명  \
# pageId
# 14915891  2017-12-14T18:12:43.697+09:00
# 35692809  2019-06-28T10:32:58.303+09:00  리니지M 게시판 문장별 감성분류 태그 코퍼스  장철훈
# ...

# %%
attach_info = info.get_attachment()
attach_info
# Out:
# ...
#                                                        name  \
# pageId
# 35692809    20190723_리니지M_게시판_문장별_감성분류_데이터_12000_20000.xlsx
# 35692809  리니지M_게시판_문장별_감성분류_데이터_12000_20000_20190717(완료)...
# 35692809  리니지M_게시판_문장별_감성분류_데이터_12000_20000_20190716.xls...
# 35692809  리니지M_게시판_문장별_감성분류_데이터_12000_20000_20190715.xls...
# 35692809    리니지M_게시판_문장별_감성분류_데이터_12000_20000_20190712.xlsx
# ...                                                     ...
# 29396663                      nc_topic_답변모음_드림이_181108.xlsx
# 29396663                            문체변환_코퍼스_분류체계_1107.xlsx
# 29396663                              (11.05)NC_질문_리스트.xlsx
# 29396663                              (11.02)NC_질문_리스트.xlsx
# 33389353                 PAIGE_2.0_야구공작소_퀴즈_Pool_05.27.xlsx
#
#                                                         url  \
# pageId
# 35692809  http://172.20.93.58:8090/download/attachments/...
# 35692809  http://172.20.93.58:8090/download/attachments/...
# ...

# %%
df = load_data(page_id='14916023', attachment_info=attach_info)
df
# Out:
# ...
# {'12.26_평가셋_야구공작소_평가_결과/남통현':            날짜                 질문  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
#  0  2016-05-12      코엘로는 언제 데뷔했어?         NaN         NaN         NaN
#  1  2016-05-12          코엘로의 데뷔는?         NaN         NaN         NaN
#  2  2016-05-12    코엘로의 데뷔년도는 언제야?         NaN         NaN         NaN
#  3  2016-05-12   코엘로는 데뷔를 언제 한거지?         NaN         NaN         NaN
#  4  2016-05-12  코엘로는 데뷔가 언제인지 알려줘         NaN         NaN         NaN
#  ..        ...                ...         ...         ...         ...
#  75 2016-08-05          정근우 입단 년도         NaN         NaN         NaN
#  76 2016-08-05          정근우 입단 궁금         NaN         NaN         NaN
#  77 2016-08-05      정근우 입단은 언제했어?         NaN         NaN         NaN
#  78 2016-08-05       정근우 입단한 년도가?         NaN         NaN         NaN
#  79 2016-08-05      정근우가 입단한 년도가?         NaN         NaN         NaN
#
#      Unnamed: 5  Unnamed: 6  Unnamed: 7    정답                      시스템 결과  O/X  \
# ...

# %%
import pprint

pprint.pprint(list(df.keys()))
# Out:
# ['12.26_평가셋_야구공작소_평가_결과/남통현',
#  '12.26_평가셋_야구공작소_평가_결과/이예림',
#  '12.26_평가셋_야구공작소_평가_결과/김태근',
#  '12.26_평가셋_야구공작소_평가_결과/남경무',
#  '12.26_평가셋_야구공작소_평가_결과/안되는것',
#  '12.26_평가셋_야구공작소_평가_결과/분석 결과',
#  '12.22_평가셋_야구공작소_평가_결과/이창용',
#  '12.22_평가셋_야구공작소_평가_결과/남통현',
#  '12.22_평가셋_야구공작소_평가_결과/김태근',
#  '12.22_평가셋_야구공작소_평가_결과/남경무',
#  '12.22_평가셋_야구공작소_평가_결과/이예림',
#  '12.22_평가셋_야구공작소_평가_결과/안되는것',
#  '12.22_평가셋_야구공작소_평가_결과/분석 결과',
#  '1단계평가_야구공작소_전체',
#  '12.26_평가셋_야구공작소_개별파일/남통현',
#  '12.26_평가셋_야구공작소_개별파일/이예림',
#  '12.26_평가셋_야구공작소_개별파일/김태근',
#  '12.26_평가셋_야구공작소_개별파일/남경무',
#  '12.21_평가셋_야구공작소_결과분석/이창용',
#  '12.21_평가셋_야구공작소_결과분석/남통현',
#  '12.21_평가셋_야구공작소_결과분석/김태근',
#  '12.21_평가셋_야구공작소_결과분석/남경무',
#  '12.21_평가셋_야구공작소_결과분석/이예림',
#  '12.21_평가셋_야구공작소_결과분석/분석 결과',
#  '12.21_평가셋_야구공작소_김태근님_수정/이창용',
#  '12.21_평가셋_야구공작소_김태근님_수정/남통현',
#  '12.21_평가셋_야구공작소_김태근님_수정/김태근',
#  '12.21_평가셋_야구공작소_김태근님_수정/남경무',
#  '12.21_평가셋_야구공작소_김태근님_수정/이예림',
#  '12.22_평가셋_야구공작소/이창용',
#  '12.22_평가셋_야구공작소/남통현',
# ...

# %%
df['12.18_평가셋_야구공작소/전체'].columns.tolist()
# Out:
# ['날짜',
#  '질문',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  '정답',
#  '시스템 결과',
#  'O/X']

# %%
df['12.18_평가셋_야구공작소/전체'][['날짜', '질문', '정답', '시스템 결과', 'O/X']]
# Out:
#             날짜              질문   정답                 시스템 결과         O/X
# 0   2016-04-01  오늘 넥센 2루수는 누구야  서건창    오늘 넥센 2루수는 서건창입니다.     1.000000
# 1   2016-04-01    오늘 서건창의 포지션은  2루수  오늘 서건창의 포지션은 4루수입니다.     0.000000
# 2   2016-04-01    오늘 김하성의 포지션은  유격수  오늘 김하성의 포지션은 6루수입니다.     0.000000
# 3   2016-04-01    오늘 고종욱의 포지션은  중견수  오늘 고종욱의 포지션은 8루수입니다.     0.000000
# 4   2016-04-01     오늘 박병호는 나와?  아니오   아니요. 오늘은 출전하지 않습니다.     0.000000
# ..         ...             ...  ...                    ...         ...
# 439        NaT             NaN  NaN                    NaN         NaN
# 440        NaT             NaN  NaN                     정답  251.000000
# 441        NaT             NaN  NaN                     오답  185.000000
# 442        NaT             NaN  NaN                     전체  436.000000
# 443        NaT             NaN  NaN              precision    0.575688
#
# [444 rows x 5 columns]
