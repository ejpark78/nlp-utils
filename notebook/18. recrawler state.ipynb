# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !echo '172.19.153.41  nlp-utils' >> /etc/hosts

# %%
# !pip3 install kubernetes panda
# Out:
# Looking in indexes: https://k8s:****@nlp-utils/repository/pypi/simple
# Requirement already satisfied: kubernetes in /usr/local/lib/python3.8/dist-packages (12.0.0)
# Requirement already satisfied: panda in /usr/local/lib/python3.8/dist-packages (0.3.1)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.8/dist-packages (from kubernetes) (2020.6.20)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.8/dist-packages (from kubernetes) (2.8.1)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from kubernetes) (1.22.1)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.8/dist-packages (from kubernetes) (1.25.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from kubernetes) (2.24.0)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from kubernetes) (1.14.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.8/dist-packages (from kubernetes) (0.57.0)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.8/dist-packages (from kubernetes) (50.3.2)
# Requirement already satisfied: pyyaml>=3.12 in /usr/local/lib/python3.8/dist-packages (from kubernetes) (5.3.1)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.8/dist-packages (from kubernetes) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth>=1.0.1->kubernetes) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth>=1.0.1->kubernetes) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in /usr/local/lib/python3.8/dist-packages (from google-auth>=1.0.1->kubernetes) (4.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/lib/python3/dist-packages (from requests->kubernetes) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests->kubernetes) (2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib->kubernetes) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes) (0.4.8)

# %%
import json
import pandas as pd
from kubernetes import client, config

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
class RecrawlerState(object):
    def __init__(self):
        config.load_kube_config(config_file='kube_config', context='nlp-crawler')
        self.v1 = client.CoreV1Api()
        
    @staticmethod
    def simplify_pod(pod):
        columns = {'name', 'namespace', 'creation_timestamp'}
        c_columns = {'image', 'name', 'ready', 'state'}

        metadata = pod.metadata.to_dict()
        result = {k: metadata[k] for k in columns if k in metadata}

        status = []
        c_statuses = pod.status.container_statuses
        for c_st in c_statuses:
            dict_item = c_st.to_dict()
            status_item = {k: dict_item[k] for k in c_columns if k in dict_item}

            status.append(status_item)

        result['containers'] = status
        result['status_phrase'] = pod.status.phase

        return result

    def get_pod_logs(self, namespace, pod_name, container):
        pod_logs = self.v1.read_namespaced_pod_log(
            namespace=namespace,
            name=pod_name,
            container=container,
            tail_lines=100,
        ).split('\n')

        return [line for line in pod_logs if line.strip() != '']
    
    def batch(self):
        pods = self.v1.list_namespaced_pod(namespace='recrawler')

        pod_list = {}
        for po in pods.items:
            pod_list[po.metadata.name] = self.simplify_pod(pod=po)

        result = []
        for pod_name in pod_list.keys():
            pod_logs = self.get_pod_logs(namespace='recrawler', pod_name=pod_name, container='default')

            rows = {
                'date': '',
                'category': '',
            }
            for l in sorted(pod_logs, reverse=True):
                try:
                    logs = json.loads(l)
                except:
                    continue

                for col in rows.keys():
                    if col in logs:
                        rows[col] = logs[col]

                if '' not in rows.values():
                    break

            rows['name'] = pod_name
            rows['state'] = pod_list[pod_name]['status_phrase']

            result.append(rows)    
        
        return result

# %%
recrawler_state = RecrawlerState().batch()

df = pd.DataFrame(recrawler_state)['name,category,state,date'.split(',')]

df
# Out:
#                            name     category      state        date
# 0           daum-culture-2020-0      문화/공연전시  Succeeded  2020-01-02
# 1           daum-culture-2020-1         문화/책  Succeeded  2020-01-02
# 2          daum-culture-2020-10        문화/날씨  Succeeded  2020-01-01
# 167         naver-sports-2020-4     스포츠/해외축구  Succeeded  2020-01-01
# 168         naver-sports-2020-5       스포츠/농구  Succeeded  2020-01-01
# 169         naver-sports-2020-6       스포츠/배구  Succeeded  2020-01-01
# 170         naver-sports-2020-7       스포츠/골프  Succeeded  2020-01-02
# 171         naver-sports-2020-8       스포츠/축구  Succeeded  2020-01-01
# 172         naver-sports-2020-9   스포츠/스포츠-일반  Succeeded  2020-01-01
# 173        naver-terms-detail-0               Succeeded
# 174          naver-terms-list-0                 Running
# 175          naver-terms-list-1                 Running
# 176         naver-terms-list-10                 Running
# 177         naver-terms-list-11                 Running
# 178         naver-terms-list-12                 Running
# 179         naver-terms-list-13                 Running
# 180         naver-terms-list-14                 Running
# 181         naver-terms-list-15                 Running
# 182         naver-terms-list-16                 Running
# 183         naver-terms-list-17                 Running
# 184         naver-terms-list-18                 Running
# 185         naver-terms-list-19                 Running
# 186          naver-terms-list-2                 Running
# 187         naver-terms-list-20                 Running
# 188         naver-terms-list-21                 Running
# 189         naver-terms-list-22                 Running
# 190         naver-terms-list-23                 Running
# 191         naver-terms-list-24                 Running
# 192         naver-terms-list-25                 Running
# 193         naver-terms-list-26                 Running
# 194         naver-terms-list-27                 Running
# 195         naver-terms-list-28                 Running
# 196         naver-terms-list-29                 Running
# 197          naver-terms-list-3                 Running
# 198         naver-terms-list-30                 Running
# 199         naver-terms-list-31                 Running
# 200         naver-terms-list-32                 Running
# 201         naver-terms-list-33                 Running
# 202         naver-terms-list-34                 Running
# 203         naver-terms-list-35                 Running
# 204         naver-terms-list-36                 Running
# 205          naver-terms-list-4                 Running
# 206          naver-terms-list-5                 Running
# 207          naver-terms-list-6                 Running
# 208          naver-terms-list-7                 Running
# 209          naver-terms-list-8                 Running
# 210          naver-terms-list-9                 Running
# 211             naver-tv-2020-0           TV  Succeeded  2020-01-01
# 212        naver-weather-2020-0               Succeeded  2020-01-01

# %%
df[(df['name'].str.find('-terms-') < 0) & (df['name'].str.find('naver-') >= 0) & (df['state'] == 'Running')]
# Out:
#                      name  category    state        date
# 115  naver-economy-2020-1     경제/금융  Running  2020-01-06
# 117  naver-economy-2020-3  경제/산업/재계  Running  2020-06-30
# 119  naver-economy-2020-5  경제/경제 일반  Running  2020-07-20
# 153  naver-society-2020-0   사회/사건사고  Running  2020-07-16
# 154  naver-society-2020-1     사회/교육  Running  2020-08-25
# 155  naver-society-2020-2     사회/노동  Running  2020-09-12
# 156  naver-society-2020-3     사회/언론  Running  2020-09-29
# 157  naver-society-2020-4     사회/환경  Running  2020-09-06
# 158  naver-society-2020-5   사회/인권복지  Running  2020-08-09
# 159  naver-society-2020-6   사회/식품의료  Running  2020-07-14
# 160  naver-society-2020-7     사회/지역  Running  2020-09-20
# 161  naver-society-2020-8     사회/인물  Running  2020-08-26
# 162  naver-society-2020-9   사회/사회일반  Running  2020-09-24
