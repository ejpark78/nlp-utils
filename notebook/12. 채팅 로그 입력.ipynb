# %%
# %load_ext autoreload
# %autoreload 2

# %%
from glob import glob
from chatting_log_utils import ChattingLogUtils
# Out:
# /home/workspace/mt/data/utils/elasticsearch_utils.py:21: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
f_list = glob('game_logs/*/??/*.*')
f_list
# Out:
# ['game_logs/L2/cn/l2.cn.baidu_tieba.20190125_20191216.txt.bz2',
#  'game_logs/L2/tw/l2.tw.nct_chat.20191209_20191212.txt.bz2',
#  'game_logs/LM/ko/voc_lm_chat_20191103.csv.bz2',
#  'game_logs/LM/ko/voc_lm_chat_20191106.csv.bz2',
#  'game_logs/LM/ko/voc_lm_chat_20191105.csv.bz2',
#  'game_logs/LM/ko/voc_lm_chat_20191104.csv.bz2',
#  'game_logs/LM/ko/voc_lm_chat_20191101.csv.bz2',
#  'game_logs/LM/ko/voc_lm_chat_20191102.csv.bz2',
#  'game_logs/BS/ko/bns_chat_20191203.tsv.bz2',
#  'game_logs/L2M/ko/l2m_chat_20191205.tsv.bz2']

# %%
utils = ChattingLogUtils()

utils.batch(f_list=f_list)
# Out:
# POST https://corpus.ncsoft.com:9200/corpus-game-chatting-logs/_bulk?refresh=true [status:400 request:0.011s]
# {"exception": "RequestError(400, 'x_content_parse_exception', '[1:303] [UpdateRequest] failed to parse field [doc]')", "host": "https://corpus.ncsoft.com:9200", "index": "corpus-game-chatting-logs", "level": "ERROR", "message": "저장 에러 (bulk)", "response": null}
# POST https://corpus.ncsoft.com:9200/corpus-game-chatting-logs/_bulk?refresh=true [status:400 request:0.007s]
# {"exception": "RequestError(400, 'x_content_parse_exception', '[1:302] [UpdateRequest] failed to parse field [doc]')", "host": "https://corpus.ncsoft.com:9200", "index": "corpus-game-chatting-logs", "level": "ERROR", "message": "저장 에러 (bulk)", "response": null}
# POST https://corpus.ncsoft.com:9200/corpus-game-chatting-logs/_bulk?refresh=true [status:400 request:0.012s]
# ...
