# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from text_explorer import TextExplorer
# Out:
# /home/workspace/mt/data/utils/elasticsearch_utils.py:21: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
utils = TextExplorer()

# %%
# filename = 'mt-pipeline/open-nmt/dictionary-example.bleu.json.bz2'
filename = 'mt-pipeline/moses/dictionary-example.bleu.json.bz2'

# %%
# filename = 'mt-pipeline/open-nmt/aihub-dialog.bleu.json.bz2'
# filename = 'mt-pipeline/moses/aihub-dialog.bleu.json.bz2'

# %%
utils.cache['moses'] = {}

cache = utils.cache['moses']

# %%
pd.set_option('precision', 4)

cache['df'] = utils.read_json(filename=filename)
cache['df'].head()
# Out:
#       NIST    BLEU                                                src  \
# 0   8.6735  0.1944                이번 선거 는 맥케이 ㄴ 에게 결코 쉽 지 않 을 것 이 다 .
# 1  12.7917  0.6402  고개 를 끄덕이 거나 흔들 어서 , 그 돌고래 는 단 몇 분 만 에 예술 작품 을 ...
# 2   8.3792  0.2356  활동 중 이 ㄴ 다른 요인 에 대하 아 고려 하 지 않 음 으로써 , 프로그램 은 ...
# 3   7.8468  0.3548  몇 십 년 앞 을 예측 하 ㄹ 수 없 었 기 때문 에 그 들 은 그것 에 대처 하 ...
# 4   4.6099  0.1003  회사 가 막대하 ㄴ 양 의 고객 정보 를 수집 하 지 않 는다면 실제로 고객 의 신...
#
#                                                  tgt  \
# 0  By no means will this election be easy for McC...
# 1  By nodding and wagging its head , Xiao is able...
# 2  By not accounting for the other factors which ...
# 3  By not being able to look decades ahead , they...
# 4  By not collecting enormous amounts of data abo...
#
#                                                  tst
# 0        This election is easy for McCain will not .
# 1  By nodding and wagging its head , Xiao is an a...
# 2  an active for the other factors By not account...
# ...

# %%
text_summary = utils.get_summary(df=cache['df'], columns=['src', 'tgt', 'tst'], title='길이')

for k in {'bleu', 'length'}:
    display(text_summary[k].style.set_caption(k))
# Out:
# /home/workspace/mt/data/text_explorer.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   count_df['token'] = df['src'].apply(lambda x: len(x.split(' ')))
# /home/workspace/mt/data/text_explorer.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   count_df['length'] = df['src'].apply(lambda x: len(x))
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
pd.set_option('display.max_colwidth', 0)
pd.set_option('precision', 1)

# %%
bleu_range = utils.get_bleu_range(df=cache['df'])

bleu_range.style.set_caption('BLEU 범위')
# Out:
# 'BLEU: 0.1000 ~ 0.2000, size: 78,142'
# /home/workspace/mt/data/text_explorer.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   count_df['token'] = df['src'].apply(lambda x: len(x.split(' ')))
# /home/workspace/mt/data/text_explorer.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   count_df['length'] = df['src'].apply(lambda x: len(x))
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
# ...
