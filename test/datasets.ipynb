# %%
# !pip3 install nlplab

# %%
import sys

sys.path.append('/home/ejpark/workspace/nlplab/venv/lib/python3.8/site-packages')

# sys.path[0] = '/home/ejpark/workspace/nlplab/venv/lib/python3.8/site-packages'
sys.path
# Out:
# ['/home/ejpark/workspace/nlplab/test',
#  '/usr/lib/python38.zip',
#  '/usr/lib/python3.8',
#  '/usr/lib/python3.8/lib-dynload',
#  '',
#  '/home/ejpark/.local/lib/python3.8/site-packages',
#  '/usr/local/lib/python3.8/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.8/dist-packages',
#  '/home/ejpark/.local/lib/python3.8/site-packages/IPython/extensions',
#  '/home/ejpark/.ipython',
#  '/home/ejpark/workspace/nlplab/venv/lib/python3.8/site-packages']

# %%
# !pip3 show nlplab
# Out:
# Name: nlplab
# Version: 1.0.0
# Summary: nlplab 데이터셋 배포 라이브러리
# Home-page: http://galadriel02.korea.ncsoft.corp/searchtf/pypi/nlplab
# Author: ejpark
# Author-email: ejpark@ncsoft.com
# License: Apache License Version 2.0
# Location: /home/ejpark/workspace/nlplab/venv/lib/python3.8/site-packages
# Requires: wheel, webdav, setuptools, urllib3, twine, requests, pandas, bs4, tqdm, elasticsearch, minio
# Required-by:

# %%
import pandas as pd
from nlplab.datasets.datasets import DataSets

# %%
ds = DataSets()

# %%
ds.list()
# Out:
# [{'movie_reviews': '네이버/다음 영화 리뷰'},
#  {'youtube/replies': '유튜브 댓글'},
#  {'bbs-lineage': 'elasticsearch 코퍼스'},
#  {'bbs-lineagem': 'elasticsearch 코퍼스'},
#  {'bbs-lineagem-keywords': 'elasticsearch 코퍼스'},
#  {'corpus-bbs-lineagem': 'elasticsearch 코퍼스'},
#  {'corpus-bitext': 'elasticsearch 코퍼스'},
#  {'corpus-bitext-aspec-jaen': 'elasticsearch 코퍼스'},
#  {'corpus-bitext-aspec-jazh': 'elasticsearch 코퍼스'},
#  {'corpus-bitext-koen': 'elasticsearch 코퍼스'},
#  {'corpus-bitext-ted-multilang': 'elasticsearch 코퍼스'},
#  {'corpus-bitext-ted-south_asia': 'elasticsearch 코퍼스'},
#  {'corpus-evaluation': 'elasticsearch 코퍼스'},
#  {'corpus-game-chatting-lineagem': 'elasticsearch 코퍼스'},
#  {'corpus-game-chatting-logs': 'elasticsearch 코퍼스'},
#  {'corpus-naver_sports_quote-2019': 'elasticsearch 코퍼스'},
#  {'corpus-sentence-jisikman': 'elasticsearch 코퍼스'},
#  {'corpus-wiki-en': 'elasticsearch 코퍼스'},
#  {'corpus-wiki-id': 'elasticsearch 코퍼스'},
#  {'corpus-wiki-ja': 'elasticsearch 코퍼스'},
# ...

# %%
inven = ds.load(name='crawler-bbs-inven-2017')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-4f04e2c599f5> in <module>
# ----> 1 inven = ds.load(name='crawler-bbs-inven-2017')
#
# ~/workspace/nlplab/venv/lib/python3.8/site-packages/nlplab/datasets/datasets.py in load(self, name, tag)
#      63
#      64         if meta['location'] == 'elasticsearch':
# ---> 65             return self.load_elasticsearch_data(meta=meta, name=name)
#      66
#      67         return None
#
# ~/workspace/nlplab/venv/lib/python3.8/site-packages/nlplab/datasets/datasets.py in load_elasticsearch_data(self, meta, name)
#      70         filename = '{}/{}.json.bz2'.format(meta['local_path'], name)
#      71         if isfile(filename) is False:
# ---> 72             self.es.export(filename=filename, index=name)
#      73
#      74         result = []
#
# ...

# %%
movie_reviews = ds.load(name='movie_reviews')
movie_reviews
# Out:
# {'daum': [{'no': 1,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '담쨩',
#    'date': '2020-10-23T00:09:29+0900',
#    'id': 598230936,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '그 시절 꿈틀거려준 여성들에게 감사하며',
#    'childCount': 0,
#    'likeCount': 161,
#    'dislikeCount': 27,
#    'recommendCount': 134},
#   {'no': 2,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'Terry',
#    'date': '2020-10-23T21:23:13+0900',
#    'id': 598528291,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '이 정도면 저예산으로 기승전결 잘 갖춰 재밌게 만든 영화다. 연기 구멍도 하나 없고 스케일이 크진 않으나 아기자기하게 곳곳에서 생각할 사회적 구성원으로서의 명제를 던진다. 평점 테러하는 애들 영화 발로 봤냐??',
#    'childCount': 0,
#    'likeCount': 133,
#    'dislikeCount': 20,
#    'recommendCount': 113},
#   {'no': 3,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '희망',
#    'date': '2020-10-22T01:00:20+0900',
#    'id': 598230170,
#    'postId': 149729190,
#    'rating': 8,
# ...

# %%
df_naver = pd.DataFrame(movie_reviews['naver'])
df_naver
# Out:
#             no                                              title    code  \
# 0            1  108명의 여자와 섹스하는 방법 (108: REVENGE AND ADVENTURE ...  193996
# 1            2  108명의 여자와 섹스하는 방법 (108: REVENGE AND ADVENTURE ...  193996
# 2            3                 16세의 사운드트랙 (Soundtrack to Sixteen)  194004
# 3            4                 16세의 사운드트랙 (Soundtrack to Sixteen)  194004
# 4            5                 16세의 사운드트랙 (Soundtrack to Sixteen)  194004
# ...        ...                                                ...     ...
# 863138  863139                                             크게 될 놈  159845
# 863139  863140                                             크게 될 놈  159845
# 863140  863141                                             크게 될 놈  159845
# 863141  863142                                             크게 될 놈  159845
# 863142  863143                                             크게 될 놈  159845
#
#        score                                            comment is_viewer  \
# ...

# %%
df_daum = pd.DataFrame(movie_reviews['daum'])
df_daum
# Out:
#             no         title    code username                      date  \
# 0            1    삼진그룹 영어토익반  135112       담쨩  2020-10-23T00:09:29+0900
# 1            2    삼진그룹 영어토익반  135112    Terry  2020-10-23T21:23:13+0900
# 2            3    삼진그룹 영어토익반  135112       희망  2020-10-22T01:00:20+0900
# 3            4    삼진그룹 영어토익반  135112      알렉스  2020-10-24T16:51:11+0900
# 4            5    삼진그룹 영어토익반  135112      구도연  2020-10-24T01:47:21+0900
# ...        ...           ...     ...      ...                       ...
# 337716  337717  어벤져스: 인피니티 워   93251   환영환영환영  2018-04-29T16:32:13+0900
# 337717  337718  어벤져스: 인피니티 워   93251       동우  2018-04-29T16:04:13+0900
# 337718  337719  어벤져스: 인피니티 워   93251     coch  2018-04-29T16:02:09+0900
# 337719  337720  어벤져스: 인피니티 워   93251      이등병  2018-04-29T16:00:24+0900
# 337720  337721  어벤져스: 인피니티 워   93251     복근좋다  2018-04-29T15:49:00+0900
#
#                id     postId  rating  \
# 0       598230936  149729190      10
# ...

# %%
ds = DataSets(name='youtube/replies')

# %%
youtube = ds.load()

# %%
df_mtd = pd.DataFrame(youtube['mtd'])
df_mtd
# Out:
#                                id     video_id  \
# 0      UgwqnetUpglSE5UMpRJ4AaABAg  TnfMg3VS4N0
# 1      Ugx9JeaWZoB5OMf4LI94AaABAg  TnfMg3VS4N0
# 2      UgyVXlN8yU--MeBH-_F4AaABAg  TnfMg3VS4N0
# 3      UgxuSbmOp9imTTEfL8h4AaABAg  TnfMg3VS4N0
# 4      UgwbLj-PnXFdjU2NBXh4AaABAg  8DjJm0Mpxmw
# ...                           ...          ...
# 81168  UgxOafccrOefSQGV7tN4AaABAg  X8ZfmVuaV14
# 81169  UgxKfNqXaREPu-4o0bR4AaABAg  X8ZfmVuaV14
# 81170  Ugw1fEBhvh6eGrIjOr54AaABAg  X8ZfmVuaV14
# 81171  UgyRazxKpPdYwnnRpWN4AaABAg  X8ZfmVuaV14
# 81172  UgwLcxz5cwxQgyB-Rl54AaABAg  X8ZfmVuaV14
#
#                                              video_title          username  \
# 0      Test of the Reformer - Lineage 2 NA Classic - ...  Nerijus Raštikis
# 1      Test of the Reformer - Lineage 2 NA Classic - ...         Kristhian
# 2      Test of the Reformer - Lineage 2 NA Classic - ...        Zac Kreiss
# 3      Test of the Reformer - Lineage 2 NA Classic - ...           Wakanda
# ...
