# %%
# !pip3 install nlplab

# %%
# !pip3 show nlplab
# Out:
# Name: nlplab
# Version: 1.0.0
# Summary: nlplab 데이터셋 배포 라이브러리
# Home-page: http://galadriel02.korea.ncsoft.corp/searchtf/pypi/nlplab
# Author: ejpark
# Author-email: ejpark@ncsoft.com
# License: Apache License Version 2.0
# Location: /home/ejpark/workspace/nlplab/venv/lib/python3.8/site-packages
# Requires: minio, wheel, requests, webdav, setuptools, pandas, elasticsearch, bs4, urllib3, twine, tqdm
# Required-by:

# %%
import sys

sys.path.append('/home/ejpark/workspace/nlplab/venv/lib/python3.8/site-packages')
sys.path
# Out:
# ['/home/ejpark/workspace/nlplab/test',
#  '/usr/lib/python38.zip',
#  '/usr/lib/python3.8',
#  '/usr/lib/python3.8/lib-dynload',
#  '',
#  '/home/ejpark/.local/lib/python3.8/site-packages',
#  '/usr/local/lib/python3.8/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.8/dist-packages',
#  '/home/ejpark/.local/lib/python3.8/site-packages/IPython/extensions',
#  '/home/ejpark/.ipython',
#  '/home/ejpark/workspace/nlplab/venv/lib/python3.8/site-packages']

# %%
import pandas as pd
from nlplab.datasets import DataSets

# %%
ds = DataSets()

# %%
ds.list()

# %%
ds = DataSets(name='youtube/replies')

# %%
ds.upload(name='movie_reviews')

# %%
ds.upload(name='youtube/replies')

# %%
replies = ds.load()

# %%
ds.upload(name='movie_reviews')

# %%
replies = ds.load(name='movie_reviews', tag='naver')

# %%
df = pd.DataFrame(replies['naver'])
df
# Out:
#               no                                              title    code  \
# 0              1  108명의 여자와 섹스하는 방법 (108: REVENGE AND ADVENTURE ...  193996
# 1              2  108명의 여자와 섹스하는 방법 (108: REVENGE AND ADVENTURE ...  193996
# 2              3                 16세의 사운드트랙 (Soundtrack to Sixteen)  194004
# 3              4                 16세의 사운드트랙 (Soundtrack to Sixteen)  194004
# 4              5                 16세의 사운드트랙 (Soundtrack to Sixteen)  194004
# ...          ...                                                ...     ...
# 1071094  1071095                                                 당갈  157243
# 1071095  1071096                                                 당갈  157243
# 1071096  1071097                                                 당갈  157243
# 1071097  1071098                                                 당갈  157243
# 1071098  1071099                                                 당갈  157243
#
#         score                                            comment is_viewer  \
# 0           1                                      미포린 이젠 막나가는구나
# 1           1                                      미포린 이젠 막나가는구나
# 2           6                            공감성 수치를 불러일으키는 16세의 기억들       관람객
# 3           9                            독일식 영어에 때묻지않은 이팔청춘에 조으네
# 4           9  저격당했다 내 취향도 내 과거도난 왜 이렇게 이 영화가 사랑스럽지ㅠ?하나부터 열까지...       관람객
# ...       ...                                                ...       ...
# 1071094    10                재밌고 통쾌하고 멋있었다. 영화관에서 보길 정말 잘함. 당갈당갈
# 1071095    10  너무좋다.세번봤다. 이좋은영화를 왜 한참늦은 지금에서야 개봉한건지 그리고 노래가 없...
# 1071096    10         상영하는 관이 잘 없어서....찾아서 봐야했지만  인생영화도 같이 찾았습니다
# 1071097     9                     뻔하지만 우리에게 필요한 이야기, 재미있고 감동적이다!       관람객
# 1071098    10  오랫만에 영화다운 영화인생영화 봤어요평범이 별 다섯개가 끝이라 너무 아쉬워요정말 지...
#
#                         author                       date sympathy  \
# 0                bai(bain****)  2020-06-11T00:29:00+09:00        1
# 1                bai(bain****)  2020-06-11T00:29:00+09:00        1
# 2                 민경(jenn****)  2020-07-30T14:20:00+09:00        0
# 3              초전동삼촌(whit****)  2020-07-05T16:00:00+09:00        1
# 4                 ㅇㅇ(toal****)  2020-07-02T21:03:00+09:00        1
# ...                        ...                        ...      ...
# 1071094        aaaaa(sh76****)  2018-05-13T22:12:00+09:00        1
# 1071095           니이(bast****)  2018-05-13T15:37:00+09:00        1
# 1071096               wnal****  2018-05-13T15:27:00+09:00        1
# 1071097  Jackson Ryu(gjtm****)  2018-05-13T15:24:00+09:00        1
# 1071098          찌니쌤(pret****)  2018-05-13T14:02:00+09:00        1
#
#         not_sympathy
# 0                  1
# 1                  1
# 2                  0
# 3                  2
# 4                  2
# ...              ...
# 1071094            0
# 1071095            0
# 1071096            0
# 1071097            0
# 1071098            0
#
# [1071099 rows x 10 columns]

# %%
replies
# Out:
# {'daum': [{'no': 1,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '담쨩',
#    'date': '2020-10-23T00:09:29+0900',
#    'id': 598230936,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '그 시절 꿈틀거려준 여성들에게 감사하며',
#    'childCount': 0,
#    'likeCount': 161,
#    'dislikeCount': 27,
#    'recommendCount': 134},
#   {'no': 2,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'Terry',
#    'date': '2020-10-23T21:23:13+0900',
#    'id': 598528291,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '이 정도면 저예산으로 기승전결 잘 갖춰 재밌게 만든 영화다. 연기 구멍도 하나 없고 스케일이 크진 않으나 아기자기하게 곳곳에서 생각할 사회적 구성원으로서의 명제를 던진다. 평점 테러하는 애들 영화 발로 봤냐??',
#    'childCount': 0,
#    'likeCount': 133,
#    'dislikeCount': 20,
#    'recommendCount': 113},
#   {'no': 3,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '희망',
#    'date': '2020-10-22T01:00:20+0900',
#    'id': 598230170,
#    'postId': 149729190,
#    'rating': 8,
#    'content': '이 영화 아주 재미있다. 부조리한 면들이 있었고 여직원들에대한 인권과 평등의식이 비교적 낮았던 1990년대의 사회상과 회사생활을 보여주면서 영화는 코믹하게 시작한다.\r\n능력은 있지만 회사에서 학력으로 인해 부당한 대우와 시선을 받는 상고(상업고등학교)출신의 삼전기업 고졸여직원들이 당당하게 그 상황들을 헤쳐나가는 모습들이  재치있고 톡톡튀는 대사들과 함께 빠른 템포로 펼쳐 진다.\r\n세 고졸직원 역할을 훌륭히 소화한 고아성을 비롯한 세 배우들의 연기력 좋고 박혜수의 배역과 연기가 매력있다.\r\n가슴울컥한 장면도 있고 통쾌한 후반과 유쾌한 라스트가 좋다.\r\n잘 만든 영화다.',
#    'childCount': 0,
#    'likeCount': 87,
#    'dislikeCount': 11,
#    'recommendCount': 76},
#   {'no': 4,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '알렉스',
#    'date': '2020-10-24T16:51:11+0900',
#    'id': 598775327,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '맘이 애려온다\n그시절 아무것도 모르고 그저 주는 녹을 먹고\n시키는데로  해야 되는 거라 알고 일했으니 \n\n지난 세월 돌이켜 보면  생각했던 일보다\n회사에서 시키는게 사회통념이라 묵인하고\n흘러 갔던것이 후회스럽다!\n\n많이 변했지만  아직도 변해야 하는 세상이다!',
#    'childCount': 0,
#    'likeCount': 70,
#    'dislikeCount': 9,
#    'recommendCount': 61},
#   {'no': 5,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '구도연',
#    'date': '2020-10-24T01:47:21+0900',
#    'id': 598588278,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '올해 본 영화중에 최고의 영화',
#    'childCount': 0,
#    'likeCount': 65,
#    'dislikeCount': 15,
#    'recommendCount': 50},
#   {'no': 6,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '도로도비',
#    'date': '2020-10-24T20:35:48+0900',
#    'id': 598846148,
#    'postId': 149729190,
#    'rating': 10,
#    'content': "'직장판 써니'라는 말에 공감이 간다.\n주인공들이 고아성, 이솜, 박혜수와 조연분들 여성위주다보니 여성편향적 측면으로 볼 수 있는데 '개미들의 반란'을 극대화하기 위한  장치로 보면 좋겠다. 미투운동이니 괜히 그런걸로 몰아서 부정적측면으로 보지말고. \n\n고졸사원으로부터 시작되었지만 '한국인'들의 글로벌 썁썁놈에 대한 반란!\n\n지렁이도 밟으면 꿈틀한다.",
#    'childCount': 0,
#    'likeCount': 57,
#    'dislikeCount': 7,
#    'recommendCount': 50},
#   {'no': 7,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '하쿠나마타타',
#    'date': '2020-10-24T12:29:23+0900',
#    'id': 598708662,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '2020년 개봉한 영화들 중 제일 재밌게 본 영화였음..코로나때 개봉한게 아쉬울정도ㅠ',
#    'childCount': 0,
#    'likeCount': 56,
#    'dislikeCount': 12,
#    'recommendCount': 44},
#   {'no': 8,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '안녕이라는말은하지않아',
#    'date': '2020-10-22T21:04:57+0900',
#    'id': 598230695,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '유아인 나오는거 보려다가 삼진그룹 봤는데 기대이상 재밌었어여 처음부터 끝까지 스토리도 좋았어요',
#    'childCount': 0,
#    'likeCount': 56,
#    'dislikeCount': 12,
#    'recommendCount': 44},
#   {'no': 9,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '별빛바램',
#    'date': '2020-10-23T03:38:25+0900',
#    'id': 598231001,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '나도 직장에서 커피타고 복사하고 허드렛일 도맡아한 경험이 있기에 고졸사원에 공감이 갔다...재밌게 잘봤어용....노래도 넘 신났다...이젠 모든걸 다시 시작해....',
#    'childCount': 0,
#    'likeCount': 57,
#    'dislikeCount': 18,
#    'recommendCount': 39},
#   {'no': 10,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '박하은',
#    'date': '2020-10-24T12:18:22+0900',
#    'id': 598705305,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '진짜 재밌어요 올해 본 영화중에 최고 대박나세요',
#    'childCount': 0,
#    'likeCount': 51,
#    'dislikeCount': 14,
#    'recommendCount': 37},
#   {'no': 11,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '은행털이',
#    'date': '2020-10-25T18:24:43+0900',
#    'id': 599100553,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '재미있었지만 마냥 웃을수만은 없었고 보는 내내 그시절 그녀들이 생각나 가슴이 아팠다 \n유니폼이 없어지고 사무실에서 담배를 피우는 사람들은 없어졌지만  여전히  낮은 임금을 받고 승진에서 배제당하는  이제 50이 넘었을 지금의 그녀들에게 이 영화는 어떤 의미일까 ......\n조금은 부족해도 그녀들을 소환해준것에 감사한다',
#    'childCount': 0,
#    'likeCount': 34,
#    'dislikeCount': 6,
#    'recommendCount': 28},
#   {'no': 12,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '유이',
#    'date': '2020-10-25T22:56:51+0900',
#    'id': 599165004,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '너무 무겁지않게 유쾌하지만 정말 진지하게 내일을 위해 열심히 걸어가는 삼진그룹 여직원분들 멋있었어요 추천합니다!\n많은 사건들과의 연결성이 적절하게 잘연결되어있고\n눈치채신분들 있었겠지만ㅋ\n이영화 투자사가 롯데인게 숨겨진 킬링포인트였다는 생각이 들었네요\n\n주인공 삼인방분들 열연도 매주 좋았어요\n올해 나왔던 한국영화중 가장 잘만든 영화였다에 한표보냅니다\n감독님 배우님 제작진분들 좋은영화 보게 해주셔서 감사합니다ㅋ',
#    'childCount': 0,
#    'likeCount': 27,
#    'dislikeCount': 5,
#    'recommendCount': 22},
#   {'no': 13,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'PliNy',
#    'date': '2020-10-25T07:44:29+0900',
#    'id': 598936953,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '그 시절 레트로 감성도 적당히 자극하면서..\n메인 스토리는 나름 흔하지만.. 군더더기 없이 깔끔.\n이 나라의 재벌 세습 불법 탈법 비리 문제도 적당히\n까주는 주제의식도 좋음.\n보면서 떠오르는 게 딱 론스타나 삼숑이 떠오르더만.\n암튼.. 간만에 처음부터 엔딩까지 개운했던 영화~',
#    'childCount': 0,
#    'likeCount': 27,
#    'dislikeCount': 6,
#    'recommendCount': 21},
#   {'no': 14,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '오렌지',
#    'date': '2020-10-23T22:51:51+0900',
#    'id': 598557790,
#    'postId': 149729190,
#    'rating': 8,
#    'content': '아이 캔 두 잇, 유 캔 두 잇, 위 캔 두 잇! \n커리어우먼~ 용감한 세 친구!  꿀잼~^^',
#    'childCount': 0,
#    'likeCount': 25,
#    'dislikeCount': 7,
#    'recommendCount': 18},
#   {'no': 15,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '신유나',
#    'date': '2020-10-23T19:03:52+0900',
#    'id': 598471414,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '재밌었어요!!',
#    'childCount': 0,
#    'likeCount': 27,
#    'dislikeCount': 10,
#    'recommendCount': 17},
#   {'no': 16,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '홍수정',
#    'date': '2020-10-24T18:15:44+0900',
#    'id': 598799717,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '박혜수 진짜 좋다 ㅠ 계산하는연기...ㅠ',
#    'childCount': 0,
#    'likeCount': 17,
#    'dislikeCount': 4,
#    'recommendCount': 13},
#   {'no': 17,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '김고은',
#    'date': '2020-10-22T17:01:13+0900',
#    'id': 598230560,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '작고 작은 존재들도 뭉치면 강하다는 걸 보여주는 영화였습니다',
#    'childCount': 0,
#    'likeCount': 14,
#    'dislikeCount': 3,
#    'recommendCount': 11},
#   {'no': 18,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '뽀흔히',
#    'date': '2020-10-24T10:46:02+0900',
#    'id': 598675865,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '처음엔 영화를 보는내내 화도 너무나도 답답하기도했지만 보다보니 속이 뻥 뚫렸다 . 완전 사이다! 역시 여성들도 위대하다는걸 보여준거같다. 슬프기도 했지만 중간중간 너무 웃긴 부분이 많아서 영화 보는내내 지루함을 못 느꼈던거같다. 직장판 써니인듯하다.코로나때매 영화본지 오래였는데 이 영화를 보고 돈이 아깝지 않았다. 왠만하면 평점 안남기는데 추천추천 하고싶다.',
#    'childCount': 0,
#    'likeCount': 13,
#    'dislikeCount': 2,
#    'recommendCount': 11},
#   {'no': 19,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '다시일어서는그날',
#    'date': '2020-10-26T22:50:28+0900',
#    'id': 599470218,
#    'postId': 149729190,
#    'rating': 8,
#    'content': '이 영화를 페미영화라고 비판하는 무지한 사람들은 도대체가 무슨 생각을 하고 사는건지? 당시의 시대상을 표현하기 위한 수단까지 그렇게 폄훼한다면 시대상황을 어떻게 표현하라는 것인지 모르겠네 정말!!!  스토리,개연성, 사실묘사, 연기, 주제까지 잘 표현된 영화인데 도대체 뭐가 문제인지? 오랜만에 괜찮은 영화를 보게 되어서 좋았네요.',
#    'childCount': 0,
#    'likeCount': 16,
#    'dislikeCount': 6,
#    'recommendCount': 10},
#   {'no': 20,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '온유',
#    'date': '2020-10-24T12:24:51+0900',
#    'id': 598707265,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '와... 잼나네 ㅎ\n옛날 생각나고... 추천!!!!!',
#    'childCount': 0,
#    'likeCount': 15,
#    'dislikeCount': 5,
#    'recommendCount': 10},
#   {'no': 21,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'RSM',
#    'date': '2020-10-23T22:25:38+0900',
#    'id': 598550476,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '제 생애 최고의 영화였습니다.  정말  정의롭고  뭉클했네요.\n아이들에게도  본보기가 되는 영화였구요.',
#    'childCount': 0,
#    'likeCount': 11,
#    'dislikeCount': 1,
#    'recommendCount': 10},
#   {'no': 22,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '호롤롤로',
#    'date': '2020-10-24T10:16:03+0900',
#    'id': 598665104,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '정말 오랜만에 재밌게 본 영화다',
#    'childCount': 0,
#    'likeCount': 14,
#    'dislikeCount': 6,
#    'recommendCount': 8},
#   {'no': 23,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '그린티휘핑많이',
#    'date': '2020-10-25T18:59:07+0900',
#    'id': 599109804,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '현실고증 굿 ㅋㅋㅋㅋ 오랜만에 추억에 잠겼어요',
#    'childCount': 0,
#    'likeCount': 11,
#    'dislikeCount': 3,
#    'recommendCount': 8},
#   {'no': 24,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '반짝반짝빛나는',
#    'date': '2020-10-23T15:11:10+0900',
#    'id': 598398232,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '너무 재밌다  역시 세상은 여성이 구한다!',
#    'childCount': 0,
#    'likeCount': 38,
#    'dislikeCount': 31,
#    'recommendCount': 7},
#   {'no': 25,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '넌무지개같다',
#    'date': '2020-10-25T00:54:33+0900',
#    'id': 598903672,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '꿈틀이던 용기있는 사람들',
#    'childCount': 0,
#    'likeCount': 10,
#    'dislikeCount': 3,
#    'recommendCount': 7},
#   {'no': 26,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '이지연',
#    'date': '2020-10-25T00:41:46+0900',
#    'id': 598902058,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '가볍게 볼수 있지만 묵직한 메세지가 담겨있는 영화',
#    'childCount': 0,
#    'likeCount': 8,
#    'dislikeCount': 1,
#    'recommendCount': 7},
#   {'no': 27,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '슈미니',
#    'date': '2020-10-24T15:53:21+0900',
#    'id': 598760429,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '유쾌하게 잘 봤습니다',
#    'childCount': 0,
#    'likeCount': 8,
#    'dislikeCount': 1,
#    'recommendCount': 7},
#   {'no': 28,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '산책',
#    'date': '2020-10-24T22:03:06+0900',
#    'id': 598870437,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '완전 대박 딱 내시절을 영화로 그린~~~ 그때 현실과 많이 비슷했고 짜임새 좋고~ 연기는 더 좋고~~올해  제일 재미있게 본 영화예요~~',
#    'childCount': 0,
#    'likeCount': 10,
#    'dislikeCount': 4,
#    'recommendCount': 6},
#   {'no': 29,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '모아모아',
#    'date': '2020-10-30T15:38:13+0900',
#    'id': 600884947,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '꼭 보세요~블록버스터만 잼있는게 아닙니다~90년대 옛 향수에 젖어 보시구 추리와 유머도 있는 영화에요~^^\n즐겁게 봤습니다.보고 나오자마자 댓글담.',
#    'childCount': 0,
#    'likeCount': 7,
#    'dislikeCount': 1,
#    'recommendCount': 6},
#   {'no': 30,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '라라스윗',
#    'date': '2020-10-22T17:45:28+0900',
#    'id': 598230574,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '상상 가능한 재미를 예상하고 갔는데 꼭 생각처럼 흘러가지만은 않아서 더 재밌었어요!\r\n그리고 다들 연기를 너무 잘해서 불편함 없이 봤습니다',
#    'childCount': 0,
#    'likeCount': 7,
#    'dislikeCount': 1,
#    'recommendCount': 6},
#   {'no': 31,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '얼그레이홍차',
#    'date': '2020-10-25T21:43:43+0900',
#    'id': 599150996,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '심지 굳은 여성을 보는 즐거움. 여돕여',
#    'childCount': 0,
#    'likeCount': 9,
#    'dislikeCount': 4,
#    'recommendCount': 5},
#   {'no': 32,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '이윤희',
#    'date': '2020-10-23T21:08:15+0900',
#    'id': 598522407,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '재밌음',
#    'childCount': 0,
#    'likeCount': 9,
#    'dislikeCount': 4,
#    'recommendCount': 5},
#   {'no': 33,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '달다구리',
#    'date': '2020-10-23T01:03:21+0900',
#    'id': 598230967,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '진짜 재밌음!! 요즘 레트로에 빠져서 그런지 이런 90년대 패션 감성 좋았고 내용도 재밌었다~!!',
#    'childCount': 0,
#    'likeCount': 9,
#    'dislikeCount': 4,
#    'recommendCount': 5},
#   {'no': 34,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '은지',
#    'date': '2020-10-25T22:16:30+0900',
#    'id': 599157717,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '웃기도 하고 울기도 하고 재밌게 봤어요 ㅋㅋㅋㅋ',
#    'childCount': 0,
#    'likeCount': 8,
#    'dislikeCount': 3,
#    'recommendCount': 5},
#   {'no': 35,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'PCW',
#    'date': '2020-10-24T16:37:22+0900',
#    'id': 598771537,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '개봉날 호기심 때문에 큰 기대안하고 호기심 때문에 보고서 결론은 기대이상임',
#    'childCount': 0,
#    'likeCount': 8,
#    'dislikeCount': 3,
#    'recommendCount': 5},
#   {'no': 36,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '김미나',
#    'date': '2020-11-03T19:09:34+0900',
#    'id': 602235514,
#    'postId': 149729190,
#    'rating': 8,
#    'content': '봐야한다. \n내 시절이야기라서 눈물이 찔끔 났다. \n아파도 봐야하고 조금 모자르고 과해도 봐야한다. \n조금씩  선한쪽으로 옮겨가려는 의지가 바뀐 세상을 볼수 있게한다. 믿고싶다.\n고아성, 이솜, 박혜수배우 애썼다!!',
#    'childCount': 0,
#    'likeCount': 6,
#    'dislikeCount': 1,
#    'recommendCount': 5},
#   {'no': 37,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '메멘도',
#    'date': '2020-10-30T20:15:02+0900',
#    'id': 600982678,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '다양한 내용들이 잘 버무려져서 소화되었다는 점에서,, 그리고 3여배우의 연기 호흡이 좋았다는 점에서,, 박혜수의 연기력이 좋았다는 점에서,, 좋았다. 하지만 결말이 너무 환타지라는 점은 감점요인,, 그래도 여성, 환경, 세계화 그리고 자본이라는 각각의 대주제를 잘녹여낸듯...',
#    'childCount': 0,
#    'likeCount': 6,
#    'dislikeCount': 1,
#    'recommendCount': 5},
#   {'no': 38,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '겨울나무',
#    'date': '2020-10-26T00:14:02+0900',
#    'id': 599175956,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '과하지도 모자라지도 않은,\n욕심부리지 않고 재밌게 만든 영화.\n배우님들을 응원합니다.',
#    'childCount': 0,
#    'likeCount': 6,
#    'dislikeCount': 1,
#    'recommendCount': 5},
#   {'no': 39,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '석률',
#    'date': '2020-10-22T22:49:56+0900',
#    'id': 598230858,
#    'postId': 149729190,
#    'rating': 7,
#    'content': '고아성의 오지랖은 과하지만 이솜은 충분히 스타일리쉬 하고 박혜수도 넥스트가 기대됨',
#    'childCount': 0,
#    'likeCount': 9,
#    'dislikeCount': 5,
#    'recommendCount': 4},
#   {'no': 40,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '지원',
#    'date': '2020-10-23T01:22:07+0900',
#    'id': 598230976,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '오늘 봤는데 잼슴',
#    'childCount': 0,
#    'likeCount': 8,
#    'dislikeCount': 4,
#    'recommendCount': 4},
#   {'no': 41,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '오리',
#    'date': '2020-10-26T12:15:21+0900',
#    'id': 599294141,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '기대보다 훨씬 재미난 영화였다\n좋게 말하면 동화 나쁘게 말하면 만화같은 내용이 조금 눈에 거슬리지만\n어차피 영화는 상상력으로 시작하는 장르이니,,, 이해해줘야지\n보석처럼 빛나는 여배우들의 활약이 돋보였다\n고아성, 이솜이야 믿보배이니 말할 필요없고\n박혜수,이주영등이 돋보이는것 같았다\n특히 이주영배우의 앞날이 기대된다 \n개성넘치고 멋진 필모그래피를 쌓기를 기대해본다',
#    'childCount': 0,
#    'likeCount': 7,
#    'dislikeCount': 3,
#    'recommendCount': 4},
#   {'no': 42,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '오이',
#    'date': '2020-10-26T11:23:15+0900',
#    'id': 599277187,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '짜릿해!! 그 시대의 언니들 최고야!!! 사랑해요 삼토반💗',
#    'childCount': 0,
#    'likeCount': 5,
#    'dislikeCount': 1,
#    'recommendCount': 4},
#   {'no': 43,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '기쁘미',
#    'date': '2020-10-26T00:52:46+0900',
#    'id': 599179880,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '재밌게 봤어요',
#    'childCount': 0,
#    'likeCount': 5,
#    'dislikeCount': 1,
#    'recommendCount': 4},
#   {'no': 44,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'DoNgMy',
#    'date': '2020-10-25T00:01:39+0900',
#    'id': 598895683,
#    'postId': 149729190,
#    'rating': 8,
#    'content': '드라마였다면 어땠을까',
#    'childCount': 0,
#    'likeCount': 5,
#    'dislikeCount': 1,
#    'recommendCount': 4},
#   {'no': 45,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '아유',
#    'date': '2020-10-24T19:03:24+0900',
#    'id': 598813305,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '스토리 탄탄한 영화',
#    'childCount': 0,
#    'likeCount': 5,
#    'dislikeCount': 1,
#    'recommendCount': 4},
#   {'no': 46,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'corolong20',
#    'date': '2020-10-23T22:00:50+0900',
#    'id': 598542978,
#    'postId': 149729190,
#    'rating': 10,
#    'content': "너무 재밌다 충분히 조명되지 않았던 90년대 '커리어 우먼' 그들의 꿈이 이루어졌기를",
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 0,
#    'recommendCount': 4},
#   {'no': 47,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '풀꽃바람의노래',
#    'date': '2020-09-14T16:06:00+0900',
#    'id': 598206321,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '예고편만 봐도 재미 있겠어요~ 기대됩니다!!\r\n이 영화 마음으로 으샤으샤 보냅니다~!!',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 0,
#    'recommendCount': 4},
#   {'no': 48,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '장소민',
#    'date': '2020-10-23T23:33:53+0900',
#    'id': 598568252,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '한국에서도 이런 영화가 나올 수 있구나\n마지막 고아성 배우님의 관객에게 말을 거는 듯한 눈빛에 가슴이 벅차올랐습니다',
#    'childCount': 0,
#    'likeCount': 10,
#    'dislikeCount': 7,
#    'recommendCount': 3},
#   {'no': 49,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '권윤혜',
#    'date': '2020-10-27T00:06:48+0900',
#    'id': 599483455,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '지렁이도 밟으면 꿈틀거린다',
#    'childCount': 0,
#    'likeCount': 6,
#    'dislikeCount': 3,
#    'recommendCount': 3},
#   {'no': 50,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '소금',
#    'date': '2020-10-23T19:53:03+0900',
#    'id': 598492594,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '잼있네요.',
#    'childCount': 0,
#    'likeCount': 6,
#    'dislikeCount': 3,
#    'recommendCount': 3},
#   {'no': 51,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '햄니쨩',
#    'date': '2020-10-22T16:38:47+0900',
#    'id': 598230539,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '유쾌 상쾌 통쾌',
#    'childCount': 0,
#    'likeCount': 6,
#    'dislikeCount': 3,
#    'recommendCount': 3},
#   {'no': 52,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '무위',
#    'date': '2020-10-28T02:04:17+0900',
#    'id': 599851349,
#    'postId': 149729190,
#    'rating': 7,
#    'content': '저 시절을 살아본 고졸 여성이라면 매우 동감할 내용이 아니었을까?조금 황당하기도 하지만 배역 하나하나에  스토리와 연출이 좋다.',
#    'childCount': 0,
#    'likeCount': 5,
#    'dislikeCount': 2,
#    'recommendCount': 3},
#   {'no': 53,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '김주희',
#    'date': '2020-10-26T14:00:43+0900',
#    'id': 599327053,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '배우분들이 연기를 잘해서 몰입해서 봤습니다. 추천합니다.',
#    'childCount': 0,
#    'likeCount': 5,
#    'dislikeCount': 2,
#    'recommendCount': 3},
#   {'no': 54,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '느리게걷기',
#    'date': '2020-10-24T21:15:53+0900',
#    'id': 598859143,
#    'postId': 149729190,
#    'rating': 8,
#    'content': '재미있게 만들어졌다 생각함',
#    'childCount': 0,
#    'likeCount': 5,
#    'dislikeCount': 2,
#    'recommendCount': 3},
#   {'no': 55,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '슈퍼오렌지',
#    'date': '2020-10-24T01:58:23+0900',
#    'id': 598589172,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '여자는 여자가 돕는다.',
#    'childCount': 0,
#    'likeCount': 5,
#    'dislikeCount': 2,
#    'recommendCount': 3},
#   {'no': 56,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '가을하늘',
#    'date': '2020-11-06T14:22:54+0900',
#    'id': 603130577,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '코로나 아니었으면, 벌써 손익분기점 넘었을 영화. 뻔하지 않아서 신선했다. 자본에 휘둘리는 뻔한 요즘의 기획 영화들은 이 영화를 본받아라.  골리앗을 무너뜨리는 다윗들의 연대.',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 57,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '5로라',
#    'date': '2020-11-02T22:08:06+0900',
#    'id': 601949769,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '긴 말 안함.\n코로나만 아니었으면 대박났을 영화.',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 58,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'a-',
#    'date': '2020-11-01T23:31:13+0900',
#    'id': 601591796,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '진짜 너무 재밌었음... 모든 캐릭터가 다 살아있고 좋았고 그 캐릭터들이 무작정 선 악은 아닌데 주인공들은 선한 사람들이고 또 한편으로는 그냥 평범한 사람들이라는 게 넘... 내일도 그래 살아가야지 하고 용기를 주는 기분이었다 또 보고싶음',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 59,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '사람이먼저',
#    'date': '2020-11-01T06:27:42+0900',
#    'id': 601345322,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '왜그래 영상보고 세명 케미 너무 이뻐서 영화보러감ㅎㅎ\n90년대 추억도 새록새록.. 영화 연기, 연출 다 좋음 보기 잘한것 같음\n편하게 꼭 보시기를~~',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 60,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '뿜빠라라빠빠',
#    'date': '2020-11-01T01:53:46+0900',
#    'id': 601333417,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '재밌음!',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 61,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '누구니',
#    'date': '2020-11-01T00:20:19+0900',
#    'id': 601325637,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '시사적이고 재밌고 아주 잘 만든 영화',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 62,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '곰곰이',
#    'date': '2020-10-31T21:12:38+0900',
#    'id': 601293793,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '적역 만난 고아성씨 쏘쿨 소공녀 다솜씨 슈스케 출신 박해수씨  뿐만 아니라 땐뽀걸즈 이주영씨  모두모두 연기찐~  그 중에서 백현진 소오르으으음~~    연기 너무 잘하자낰!!!\n이 영화 너무 잼씀~~',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 63,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '검정토끼',
#    'date': '2020-10-30T21:25:42+0900',
#    'id': 601009724,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '정의가 승리할 수 있다고 믿지는 않았고 믿은 적이 없지만, 그래도 진실은 늘 진실하기에 95년 27세 정도 되는 여성들이 이룬 승리라 봤다. 마나님 나이랑 비슷한 카레의 여왕들 힘내슈.',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 64,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '넥스트',
#    'date': '2020-10-30T16:12:00+0900',
#    'id': 600897299,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '재미있게 봤어요 그때 저도 고졸로 직장생활  하며 고졸 서러움을 많이 느꼈던 그때가 떠올랐어요  그 서러운 맘 때문에 대학을 나중에 갔지만  예전  추억이 떠오르게 하는 영화였어요',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 65,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '김 혜진',
#    'date': '2020-10-29T19:40:59+0900',
#    'id': 600575489,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '스토리, 연기, 레트로한 감성 모두 잘 담아낸 좋은 영화였습니다. 처음부터 끝까지 버릴부분없이 소중한 장면들이었습니다.',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 66,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '주야',
#    'date': '2020-10-29T19:38:43+0900',
#    'id': 600574515,
#    'postId': 149729190,
#    'rating': 8,
#    'content': '의외로 내용이 진중하더군요 재미도 있고 감동도 있고 박혜수의 눈물연기가 백미',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 67,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'hyuni',
#    'date': '2020-10-27T07:06:55+0900',
#    'id': 599514684,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '재미있게 잘봤습니다. 주연, 조연 모두 연기력이 아주좋았습니다.  스토리 전개도 좋았고요. 영화보고 궁금해서 조연분들 프로필을 찾아봤습니다. 역시나~',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 68,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '둥글레차',
#    'date': '2020-10-27T00:06:31+0900',
#    'id': 599483415,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '오랜만에 정말 재밌는 영화였다',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 69,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '미성',
#    'date': '2020-10-26T17:54:57+0900',
#    'id': 599396955,
#    'postId': 149729190,
#    'rating': 10,
#    'content': "그 시대상의 모습들을 잘 담아낸 영화\n중간에 코믹스러운 대사와 장면들이\n무거운 주제와는 다르게 즐겁고 신선하게 잘 풀어내서\n재밌게 봤습니다⌯'▾'⌯",
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 70,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '조종사',
#    'date': '2020-10-26T17:34:37+0900',
#    'id': 599391003,
#    'postId': 149729190,
#    'rating': 7,
#    'content': '추억을 돋게 만드는 영화 . .\n흥행 성공 가자',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 71,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '크로미안',
#    'date': '2020-10-26T15:44:06+0900',
#    'id': 599356416,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '괜찮은 영화\n내년 추석에 티비에서 할 듯 ^^',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 72,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '봄을 닮은 너',
#    'date': '2020-10-26T10:00:08+0900',
#    'id': 599247160,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '영화 자체가 진짜 재밌었다.\n올해 본 영화 중 가장 좋았던 영화.\n이런 영화들이 많이 생겼으면 좋겠다.',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 73,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '무지가무지무지좋아',
#    'date': '2020-10-26T09:16:06+0900',
#    'id': 599232540,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '저 시대의 용기있던 여성들..최고 ^^ 보는 내내 입가에 미소만~~^^',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 74,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '영화가 좋다',
#    'date': '2020-10-26T00:38:59+0900',
#    'id': 599178568,
#    'postId': 149729190,
#    'rating': 8,
#    'content': '여배우들의 적절한 캐미가 돋보였다',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 75,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '나디아',
#    'date': '2020-10-25T23:12:07+0900',
#    'id': 599167463,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '좋은영화입니다.\n잘봤어요👍',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 76,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '나래짱',
#    'date': '2020-10-24T23:15:18+0900',
#    'id': 598886977,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '웃고 울고 공감하고',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 77,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '냥',
#    'date': '2020-10-24T15:02:56+0900',
#    'id': 598747609,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '최고',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 78,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '뚜루룹',
#    'date': '2020-10-24T14:29:36+0900',
#    'id': 598740200,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '진짜 괜찮은 영화.',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 1,
#    'recommendCount': 3},
#   {'no': 79,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '천연조미료',
#    'date': '2020-10-25T22:32:07+0900',
#    'id': 599160615,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '재미있어요~ ♡',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 0,
#    'recommendCount': 3},
#   {'no': 80,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '루키',
#    'date': '2020-10-28T08:54:47+0900',
#    'id': 599907307,
#    'postId': 149729190,
#    'rating': 6,
#    'content': '이야기와 전개 과정은 기대 이상으로 좋았다.\n그러나 결말의 연출은 좀 아쉽다. 쓸데없이 유치하다.',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 2,
#    'recommendCount': 2},
#   {'no': 81,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '호이호이',
#    'date': '2020-11-04T12:02:11+0900',
#    'id': 602421086,
#    'postId': 149729190,
#    'rating': 5,
#    'content': '왜 저는 그렇게 졸린지 모르겠네요 평점믿고 대학생 조카랑 갔는데 조카는 재밌다고 하는데..순수함을 잃어가나봅니다..',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 1,
#    'recommendCount': 2},
#   {'no': 82,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '꼴통은골로가라',
#    'date': '2020-10-31T21:53:52+0900',
#    'id': 601302509,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '자연스러운 연기, 탄탄한 시나리오~\n고아성 이솜 박혜수 삼총사 매력 쩔었음~',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 1,
#    'recommendCount': 2},
#   {'no': 83,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '이얏호',
#    'date': '2020-10-23T23:26:51+0900',
#    'id': 598566627,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '아 너무 재밌게 봤음 직장판 써니더라 ㅎㅎㅎ 아 나중에 다운받아서 다시 봐야지 ㅎㅎ',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 1,
#    'recommendCount': 2},
#   {'no': 84,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'Savior',
#    'date': '2020-10-22T15:40:18+0900',
#    'id': 598230518,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '재밌었습니다! 영화소개 프로그램에서 예고편보고 기대 3정도 했는데 대만족!!!',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 1,
#    'recommendCount': 2},
#   {'no': 85,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '막내',
#    'date': '2020-11-07T14:54:26+0900',
#    'id': 603408484,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '나도 그랬다\n가정형편으로 대학 대신 여상 나와 그래도 남들 부러워하는 증권사에 입사해 주식의 주자도 모르고 입사했던 시절\n신문정리,영수증처리,황금비율 커피 입맛에 맞게 타기\n그래도 그때가 넘 좋았다\n내인생의 황금기\n차별 또한 받아들이며 열심히 일하고 놀러다니던\n오십대 중반의 내 얘기 였다',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 86,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '미생',
#    'date': '2020-11-03T00:16:24+0900',
#    'id': 601992792,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '정말 최고입니다. 꼭 보세요. (__) ;-) 두 번 보세요.',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 87,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '으랏차차',
#    'date': '2020-11-02T23:08:35+0900',
#    'id': 601973514,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '군더더기 없이 참 잘 만든 영화였어요.',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 88,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '나미니미',
#    'date': '2020-11-02T18:17:21+0900',
#    'id': 601850941,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '모든 캐릭터들이 사랑하지 않을 수 없음!',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 89,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '민지',
#    'date': '2020-11-02T01:01:56+0900',
#    'id': 601604080,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '간만에 영화보는데 영화다운 영화 본 것 같아 기분좋네요!!ㅎㅎ\n영화 짜임새,스토리,연기 다 만점 ㅎㅎㅎ',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 90,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '파란머리천사',
#    'date': '2020-11-02T00:21:09+0900',
#    'id': 601599593,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '일단 재밌음^^!!\n사회부조리 반전\n몰입감,',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 91,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '이성원',
#    'date': '2020-11-01T09:04:56+0900',
#    'id': 601371186,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '요근래 솔직히 아주 재밌게봤다ㅎㅎ',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 92,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'Estheresther',
#    'date': '2020-10-31T22:44:52+0900',
#    'id': 601311583,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '괜찮아요 재밌게봤어요. 살짝 억지스럽지만 연기들을다 잘하하시고 사랑스라워서 다 이해되요♥보세용!!',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 93,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '말하는 감자',
#    'date': '2020-10-31T22:31:19+0900',
#    'id': 601309236,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '왜 보는 내내 눈물이 나는지. 밝은 분위기로 어두운 면을 풀어내는데 울컥하고 공감하고 오열하게 만든 영화',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 94,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '김양희',
#    'date': '2020-10-31T21:50:33+0900',
#    'id': 601301859,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '내용 전개가 어색하지않고  재미있네요.',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 95,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '아름다운세상',
#    'date': '2020-10-31T20:03:41+0900',
#    'id': 601278398,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '코로나시대 모처럼 즐거운 시간이였습니다.\n강추합니다',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 96,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'Korea Victory',
#    'date': '2020-10-31T19:57:53+0900',
#    'id': 601276905,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '두진전자 페놀사건 실화 배경\nㆍ감동+재미+의리 +교훈 모두를 담은\n좋은 영화👍  \n\n450만 예상',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 97,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '그저시민',
#    'date': '2020-10-31T18:56:31+0900',
#    'id': 601262758,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '35년전 시대 장면에서 우리 소시민들의 승리를 보여주는거 같아 기분 조오타...  우리가 개미들 만세!!!',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 98,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '정다운',
#    'date': '2020-10-31T14:52:40+0900',
#    'id': 601204830,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '감동 재미 배우들 연기 굿굿 이런 영화 좋아요',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 99,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'actorcamp',
#    'date': '2020-10-31T02:06:59+0900',
#    'id': 601059909,
#    'postId': 149729190,
#    'rating': 8,
#    'content': '페미영화가 아니라길래 보러갔습니다\n페미영화들보다  훨씬 여성에대한\n존중이 생기는 영화였습니다',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 100,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '갸덕',
#    'date': '2020-10-31T00:23:14+0900',
#    'id': 601050616,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '내용도 좋고 비리를 깨는 새로운 시도들이 너무 인상깊다.',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 101,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '김세정',
#    'date': '2020-10-30T21:55:05+0900',
#    'id': 601020025,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '재밌음. 최근에 본 영화중에 제일 괜찮았음. 등장인물들이 다 매력적이고 뻔한 전개인가했는데 반전에 또 반전이 있었고 사회적인 문제를 포함한 여러 가지 생각을 하게 만드는 영화였음. 암튼 오랜만에 맘에 드는 영화였으니 추천!',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 102,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'shellie',
#    'date': '2020-10-30T17:45:07+0900',
#    'id': 600931073,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '결말은 좀 만화같으나 디테일이 살아있는 영화.  조연배우들까지 연기도 잘하고 재미있게 봤어요',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 103,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '조현준',
#    'date': '2020-10-30T17:25:28+0900',
#    'id': 600924049,
#    'postId': 149729190,
#    'rating': 7,
#    'content': '페미 극혐하는데 전혀 페미영화아님\n주연들 다 연기도 잘하고 스토리도 좋았는데\n엑스트라로 나오시는분들은 그 치킨집에서 회의할때 \n쫌 어색하긴했음\n마지막쯤에 여직원들 회의장에서 나올때 오글거리는것도 쫌 그랬지만 전체적으로 괜찮은 영화였음\n안보신분들 영화관은 아니더라도 집에서 킬링타임용으로는 충분하니 재밌게보세요',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 104,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '고양이버스',
#    'date': '2020-10-30T16:24:34+0900',
#    'id': 600901971,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '90년대 직장생활  한 사람으로서\n공감백배\n디테일  대박이고~\n재미는 말할 것도 없고요~~~\n\n꼭 보시길~',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 105,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '소통',
#    'date': '2020-10-30T16:24:08+0900',
#    'id': 600901807,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '연기력 뛰어나고,\n내용도 재미나고.\n굿!!!!\n그 시절을 떠올리게 하는\n기분 좋은 영화~',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 106,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '망부석',
#    'date': '2020-10-29T23:58:34+0900',
#    'id': 600661650,
#    'postId': 149729190,
#    'rating': 7,
#    'content': '기대 없이 봤는데 생각보다 볼만했어요\n90년대를 느낄수 있어서 좋았어요\n그렇게 핵꿀잼은  아니지만 기대이상!!',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 107,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '이주원',
#    'date': '2020-10-29T22:04:50+0900',
#    'id': 600633511,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '한국영화가 진화하다. 살아 숨쉬는 다양한 캐릭터들로 영화의 지루함을 지웠다. 서스펜스가 끊이지 않는 드라마와는 격이 다른영화다운 영화. 상무역의 씬스틸 캐릭터의 매력이 가히 압도적이다. 단역과 조연의 하모니가 영화를 완성시키다. 범죄와의 전쟁 여성판 느낌이랄까..',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 108,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'passionate',
#    'date': '2020-10-28T00:23:07+0900',
#    'id': 599839662,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '넘 잘만들고 재미있고 빈틈없는 영화. 웃기고도 울컥거리게 만든, \n간만에 미래 기술이랍시고 맨날 이상한 괴물들 나와서 싸움 짓거리 안하는 \n인간미 넘치는 드라마 영화',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 109,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '이지현',
#    'date': '2020-10-27T23:58:34+0900',
#    'id': 599834324,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '진짜 우리나라 직장인들이 모두 봤으면',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 110,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'slslslwm',
#    'date': '2020-10-27T20:37:17+0900',
#    'id': 599771942,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '2020년 본 영화 중 최고..  개봉한 영화 중에서도 최고.. 또 보러 갈래요 ^^!',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 111,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '운수 좋은 날',
#    'date': '2020-10-26T22:35:47+0900',
#    'id': 599467190,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '남편과 재밌게 봤어요~',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 112,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '꼬마핑크',
#    'date': '2020-10-24T22:36:49+0900',
#    'id': 598877822,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '여러가지 생각을하게하는 영화네요\n 잼나게 봤어요',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 113,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '지수',
#    'date': '2020-10-24T20:48:16+0900',
#    'id': 598850380,
#    'postId': 149729190,
#    'rating': 7,
#    'content': '불의를 외면하지 않고 부정에 맞서는 그리고 연대와 공감을 잃지 않는 약자들의 유쾌한 투쟁과 승리를 담는 데 성공한, 거기에 경쾌한 전개와 상쾌한 캐릭터까지 균형 잡힌 대중적인 오락 영화. (삼총사, 과장 부장까지 고고!)',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 114,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '최경식',
#    'date': '2020-10-24T19:47:33+0900',
#    'id': 598827692,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '진짜 너무 재밌었음. 현실성 있어서 더 슬프고 웃겼던 영화',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 115,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '박진경',
#    'date': '2020-10-24T18:59:20+0900',
#    'id': 598812079,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '올해 영화중에 젤 재밌었음 ㅋ 아그리고 이솜 눈썹이랑 마지막에 파마머리 대박 ㅋ 엄마사진첩스타일ㅇ랑 똑같음 ㅜ',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 116,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '당돌한여자',
#    'date': '2020-10-22T22:56:10+0900',
#    'id': 598230863,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '재밌음',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 117,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'SSD',
#    'date': '2020-10-22T22:38:51+0900',
#    'id': 598230841,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '세배우가 캐미가 좋고 너무 재미있었어요',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 118,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '닉네임을 등록해 주세요',
#    'date': '2020-10-22T20:56:57+0900',
#    'id': 598230688,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '기대한마큼~\r\n대박^^',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 119,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '윤지숙',
#    'date': '2020-10-22T19:53:05+0900',
#    'id': 598230656,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '재미있었어요 뭉클해서 눈가가 촉촉해진 장면도 있고요 \r\n세배우 연기도 멋졌어요',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 120,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '바크',
#    'date': '2020-10-22T18:30:55+0900',
#    'id': 598230592,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '다소 무거워 질수 있는 주제를  약간의 코믹함과  심플함 으로 잘 풀어 냈다.세 배우의 케미가 둗보인다',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 121,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '로이스초코감자칩',
#    'date': '2020-10-22T14:00:25+0900',
#    'id': 598230476,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '간만에 제대로 레트로 영화라서 재밌네요 주인공들 케미도 좋고 너무 귀엽...',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 122,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '고랭이',
#    'date': '2020-10-22T13:33:51+0900',
#    'id': 598230452,
#    'postId': 149729190,
#    'rating': 8,
#    'content': '재밌네요. 이솜 갈매기 눈썹, 백현진의 변태 또라이스런 얼굴, 마미손 동생 등짝 스매싱으로 인간 만드는 고아성도 좋아요. 뿅뿅 전자오락 게임같은 엔딩크레딧도 볼 만 합니다.',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 123,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '도은',
#    'date': '2020-10-22T13:16:34+0900',
#    'id': 598230445,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '배우 연출 색감 패션 기승전결까지 완벽합니다 올해 본 영화 중에 가장 좋았네요 자극적인 요소 없이도 재미있어요',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 124,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '동방의파우스트',
#    'date': '2020-10-22T07:37:53+0900',
#    'id': 598230232,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '미흡한것도 있지만 옛다 10점!\r\n올 한국영화 중 단연 최고!',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 0,
#    'recommendCount': 2},
#   {'no': 125,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '우리집마당',
#    'date': '2020-10-25T20:23:25+0900',
#    'id': 599131550,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '회의장 장면은 넘 클리셰였지만 전반적으로 연출도 섬세하고 재밌네요!! 오랜만에 극장에서 좋은 영화 봤습니다',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 3,
#    'recommendCount': 1},
#   {'no': 126,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '차돌이',
#    'date': '2020-10-25T10:15:28+0900',
#    'id': 598974525,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '절로웃음이나는영화  요글래 재밌게본영화인거같다 삼진그룹 여사원들화이팅!!!!',
#    'childCount': 0,
#    'likeCount': 4,
#    'dislikeCount': 3,
#    'recommendCount': 1},
#   {'no': 127,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '뭐시기',
#    'date': '2020-11-02T07:59:16+0900',
#    'id': 601641083,
#    'postId': 149729190,
#    'rating': 6,
#    'content': '용두사미.. 초반러시 이후 뒤로 갈수록 떨어지는 개연성과 억지설정, 뻔한 전개로 범작으로 끝나고 말았다. 감독의 내공이 아직은 부족한 느낌.',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 2,
#    'recommendCount': 1},
#   {'no': 128,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '라무스',
#    'date': '2020-10-31T16:58:36+0900',
#    'id': 601235258,
#    'postId': 149729190,
#    'rating': 6,
#    'content': '욕심이 과했다. 90년대 감성을 잘 살리던 영화는 패놀과 여직원이린 주제를 물고 가다 삼성 홍보 영화로 빠진다. \n여러 주제를 살리려다 삼성은 가족이란 결론에 도달할 때 관객의 황당함이란. 박혜수의 연기가 진솔해서 좋았다.',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 2,
#    'recommendCount': 1},
#   {'no': 129,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'Appjh',
#    'date': '2020-10-26T22:26:13+0900',
#    'id': 599465134,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '90년대 관점에서 보면 판타지지만, 지금 시점에서 보면 너무나 공감가는 이야기.',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 2,
#    'recommendCount': 1},
#   {'no': 130,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'k2',
#    'date': '2020-10-26T17:59:51+0900',
#    'id': 599398347,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '레트로 스타일~생각보다 치밀하고 탄탄한 참신한 스토리 전개~재밌고 좋아요~12000 아깝지 않아요~연기 굿~',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 2,
#    'recommendCount': 1},
#   {'no': 131,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '만두엄마',
#    'date': '2020-10-25T18:37:59+0900',
#    'id': 599104126,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '오랜만에 불편함 없이 재미있게 보고왔어요!',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 2,
#    'recommendCount': 1},
#   {'no': 132,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '돈돈돈돈이최고야',
#    'date': '2020-10-25T14:26:37+0900',
#    'id': 599044695,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '재밌고 기승전결도 딱 맞고 흥미로운 내용. 실화 기반이라 그런지 탄탄함',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 2,
#    'recommendCount': 1},
#   {'no': 133,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '포테토칩',
#    'date': '2020-10-25T13:03:36+0900',
#    'id': 599022878,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '진짜간만에재밌게본영화ㅋㅋㅋ어제보다오늘더성장했어~!',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 2,
#    'recommendCount': 1},
#   {'no': 134,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '정현',
#    'date': '2020-10-25T00:54:04+0900',
#    'id': 598903617,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '눈물 콧물 쏟아버린... 몰입도 짱짱 연기도 짱짱 각본도 짱짱',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 2,
#    'recommendCount': 1},
#   {'no': 135,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '하늘',
#    'date': '2020-10-22T11:17:58+0900',
#    'id': 598230355,
#    'postId': 149729190,
#    'rating': 9,
#    'content': '밑에 조은심이글 악의적으로쓴 글입니다.이영화 볼만합니다.와 대단하다라고할 절정도는 아니지만 그래도 그시절 여고생들이 취직해서 열심히 살었고 페놀사건은 굉장히 큰 사건이였습니다.개연성이 스토리가 좀 부족하긴 하지만 그래도 신선한 배우들이 잘해낸 영화입니다.조은심이는 95년도에 몇살이였니?',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 2,
#    'recommendCount': 1},
#   {'no': 136,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '6737',
#    'date': '2020-10-21T15:40:57+0900',
#    'id': 598229874,
#    'postId': 149729190,
#    'rating': 8,
#    'content': '배우들의 연기가 달콤하고 보는 내가 다 뿌듯! 극 전개도 재미있었고 담고 있는 내용도 유익했습니다! 이런 알찬 영화는 많이들 보셔야되욧! :)',
#    'childCount': 0,
#    'likeCount': 3,
#    'dislikeCount': 2,
#    'recommendCount': 1},
#   {'no': 137,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '상황보고',
#    'date': '2020-11-01T21:37:10+0900',
#    'id': 601565052,
#    'postId': 149729190,
#    'rating': 7,
#    'content': '재벌과 거대 블랙메일 M&A 사이에  다툼\n\n재벌미화라는 서브리미널이 버무려진 ...',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 1,
#    'recommendCount': 1},
#   {'no': 138,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': 'mustard 홍',
#    'date': '2020-10-31T23:23:01+0900',
#    'id': 601317633,
#    'postId': 149729190,
#    'rating': 10,
#    'content': '오늘 중1 딸과 같이 봤는데, 나도 재밌고, 딸도 재밌다고.... 다들 한번 꼭 보세요.',
#    'childCount': 0,
#    'likeCount': 2,
#    'dislikeCount': 1,
#    'recommendCount': 1},
#   {'no': 139,
#    'title': '삼진그룹 영어토익반',
#    'code': '135112',
#    'username': '친위대장',
# ...
#   {'no': 944,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '천국으로 가나 지옥으로 가나혼자 가는 게 가장 빠르다',
#    'is_viewer': '',
#    'author': '박종운(pgw0****)',
#    'date': '2020-02-27T20:27:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 945,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '8',
#    'comment': '연출 영상미 미쳤어요...감동...',
#    'is_viewer': '',
#    'author': 'Jin(blac****)',
#    'date': '2020-02-27T11:57:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 946,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '연출에 감탄했습니다. 마음이 먹먹해지네요~ㅠㅠ',
#    'is_viewer': '',
#    'author': 'jiyoi(roal****)',
#    'date': '2020-02-27T00:12:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 947,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '8',
#    'comment': '배그 한번 해보지 않았지만, 마치 게임 하는 것처럼 롱테이크(?)신이 많아 몰입감만은 최고!',
#    'is_viewer': '',
#    'author': '하루키(mkha****)',
#    'date': '2020-02-27T00:06:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 948,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '7',
#    'comment': '사실감 및 현장감은 매우 뛰어남. 현장에 가있는듯한 느낌을 강하게 받을 수 있음다만 아쉬운점은 이렇다할 전쟁씬이 없는것.스케일이 큰 전쟁영화를 기대한다면 실망할 수 있을거같음',
#    'is_viewer': '',
#    'author': 'C3(csh2****)',
#    'date': '2020-02-26T12:31:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 949,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '몰입감 레전드다 요즘 재밌는거 많이나오네',
#    'is_viewer': '',
#    'author': '홍민기(mink****)',
#    'date': '2020-02-26T00:36:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 950,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '런닝타임이 끝날때 까지 이어지는 롱테이크 촬영기법은 영화 버드맨을 능가하는 긴장감의 연속이었다. 자헤드에서 보여줬던 전쟁의 참혹함을 이번 작품에서도 잘 연출했다.',
#    'is_viewer': '',
#    'author': '하얀늑대(dnjh****)',
#    'date': '2020-02-26T00:36:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 951,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '지루하진 않고 긴장감에 몰입하며 봣다',
#    'is_viewer': '',
#    'author': 'Sy(sssy****)',
#    'date': '2020-02-24T00:32:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 952,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '연출, 음향이 너무 잘 어우러져서 몰입감이 두배입니다! 정말 예술영화 그 자체!',
#    'is_viewer': '',
#    'author': '라푸TA(wjd8****)',
#    'date': '2020-02-24T00:00:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 953,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '정말 몰입감이 엄청나네요 두명만 나오는 장면도 지루하지않아요',
#    'is_viewer': '',
#    'author': '2344234(gorg****)',
#    'date': '2020-02-23T20:16:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 954,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '단순한 스토리지만 시작부터 끝까지 긴장감이 이어지며 전쟁터의 현장감이 생생하게 전해졌다. 거장 로저 디킨스의 촬영은 여전히 놀랍다.',
#    'is_viewer': '',
#    'author': '한윤경(ykha****)',
#    'date': '2020-02-23T18:06:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 955,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '8',
#    'comment': '전쟁영화가 아닌 "전쟁 드라마" 입니다. 영상미나 촬영 표현 방법들이 좋았어요:) 싸우고 터지고 스펙타클 하시는걸 좋아하신다면 지루함을 느끼실수도 있습니다.',
#    'is_viewer': '',
#    'author': '어머(yoon****)',
#    'date': '2020-02-22T11:57:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 956,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '8',
#    'comment': '포기할 수 없는 슬픈 나그네 달려라 달려라 벼랑 끝이어도 달려라',
#    'is_viewer': '',
#    'author': '짱보물(eric****)',
#    'date': '2020-02-22T11:44:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 957,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '최근에 좋은 영화 중, 포드페라리 and 1917',
#    'is_viewer': '',
#    'author': 'DO(doga****)',
#    'date': '2020-02-22T11:24:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 958,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '어우~~~~ 이건 뭐.... ㅠㅠ',
#    'is_viewer': '',
#    'author': '아침(achi****)',
#    'date': '2020-02-22T10:11:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 959,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '나에게는 그저 흘러가는 1분 1초가 그에게는 죽을만큼 붙잡고 싶은 시간이였겠지?',
#    'is_viewer': '',
#    'author': '정민(hjh4****)',
#    'date': '2020-02-22T09:14:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 960,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '8',
#    'comment': '총성과 포성 없는 전쟁터는 두려움과 공허함으로 가득채워져 있었다.박민호(yosl****) 2020.02.20 00:10',
#    'is_viewer': '',
#    'author': 'nhy6666(nhy4****)',
#    'date': '2020-02-21T23:36:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 961,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '8',
#    'comment': '조커에 호아킨이 있었다면 1917엔 촬영감독이 있었다.',
#    'is_viewer': '',
#    'author': 'fyug****',
#    'date': '2020-02-21T15:25:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 962,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '한 병사의 시선으로 체험하는 전쟁의 민낯',
#    'is_viewer': '',
#    'author': 'mar(mari****)',
#    'date': '2020-02-21T14:06:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 963,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '마지막까지 모든 것이 좋았다.',
#    'is_viewer': '',
#    'author': '붉은수선화(lesl****)',
#    'date': '2020-02-21T13:24:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 964,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '원테이크...진짜 미쳤어요..',
#    'is_viewer': '',
#    'author': '있었나(zhsl****)',
#    'date': '2020-02-21T13:03:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 965,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '정말 한 순간도 눈을 못땠습니다. 촬영기법으로 진짜 전쟁터에 있는 느낌을 그대로 받았습니다. 다른 전쟁영화처럼 터지고 죽이는 영화는 아니지만 전쟁의 참혹함을 느낄 수 있었습니다. 꼭 영화관 아이맥스로 관람 추천드려요...',
#    'is_viewer': '',
#    'author': '현탱(shh3****)',
#    'date': '2020-02-21T13:00:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 966,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '생동감있는 연출과 연기 사운드에 감동까지  오진다!  여정을 함께한 느낌!기생충이 없었다면 아카데미서 그자리들을  차지했었을거같다!',
#    'is_viewer': '',
#    'author': 'kuko****',
#    'date': '2020-02-21T12:41:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 967,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '적군에게 자비를 베풀지말자...',
#    'is_viewer': '',
#    'author': '시르비(ll57****)',
#    'date': '2020-02-21T12:11:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 968,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '전쟁 관련 영화들은 대부분 챙겨 보는데,1917 정말 대단한 영화 같네요.',
#    'is_viewer': '',
#    'author': '탐방(link****)',
#    'date': '2020-02-21T11:41:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 969,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '극 사실주의 전쟁영화 주인공과 함께 고난과 인생을 같이 헤쳐나아가며 그로인한 극심한 피로도와 몰입감에 단순 영화가 아닌 우리에 예측불허한 우리에 삶에 대해 생각하게 해주는 걸작!!!그의 인생을 체험하기 앞서서 좋은 ...',
#    'is_viewer': '',
#    'author': 'dark****',
#    'date': '2020-02-21T09:43:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 970,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '영상미가 인상적.. 시대 묘사를 굉장히 잘했음..',
#    'is_viewer': '',
#    'author': '까불지마(mado****)',
#    'date': '2020-02-21T07:08:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 971,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '영화를 계속 집중하면서 봄 ㄹㅇ... 갑자기 총소리 날때 깜짝 놀랐고',
#    'is_viewer': '',
#    'author': '우에엑(c710****)',
#    'date': '2020-02-21T07:03:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 972,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '최고',
#    'is_viewer': '',
#    'author': '귤(yons****)',
#    'date': '2020-02-21T05:36:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 973,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '9',
#    'comment': '누군가를 살리기 위해 이토록 달려본 적 있는가. 목적보다 우선되는 진정성이야말로 숭고하다.',
#    'is_viewer': '',
#    'author': 'arti****',
#    'date': '2020-02-21T02:37:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 974,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '치열하고 화려한 전쟁씬없이도  긴장감과 몰입도가 최고임  .. 감독의 연출력이 대단하다는 생각밖에 안드는 영화!',
#    'is_viewer': '',
#    'author': '날아라(pear****)',
#    'date': '2020-02-21T02:00:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 975,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '영화에 관심이 많은 사람들이라면 도대체 카메라 워킹을 어떻게 한건지 궁금할것이다. 보는 내내 메이킹 필름 꼭 봐야지 하는 생각이 듬. 롱테이크 시도도 신선하고 긴장감, 배우들의 연기도 좋음. 근데 결과적으로 왜 아카...',
#    'is_viewer': '',
#    'author': 'JKmaster(funk****)',
#    'date': '2020-02-21T01:31:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 976,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '아니 진짜 어떻게 찍었지?',
#    'is_viewer': '',
#    'author': 'B3nDJo(eldk****)',
#    'date': '2020-02-21T00:51:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 977,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '최근 본 영화 중 최고였습니다',
#    'is_viewer': '',
#    'author': '주링(tory****)',
#    'date': '2020-02-21T00:47:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 978,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '롱테이크의 끝을 보여줌 전쟁속에 들어간 느낌을 2시간내내 느낄 수 있었고 엉화끝나고 너무 벅차오름 마지막 장면은 진짜,최고다ㅠㅠㅠ',
#    'is_viewer': '',
#    'author': '왐마왐마(thfd****)',
#    'date': '2020-02-21T00:44:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 979,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '롱테이크의 미학. 30분, 40분의 롱테이크후에도 계속되는 롱테이크... 나도 보는 내내 한 호흡으로 영화속 인물과 함께 전장을 누볐다.',
#    'is_viewer': '',
#    'author': '칼국수(sang****)',
#    'date': '2020-02-21T00:43:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 980,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '와... 이건... 인생영화다..꼭 보세요..',
#    'is_viewer': '',
#    'author': '버드파웰(akqj****)',
#    'date': '2020-02-21T00:31:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 981,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '진짜 재밌음. 롱테이크로 찍어서 그런 지 몰입감이 끊기지 않았음ㅜㅜㅠ 연출이나 촬영 음악이 대단했음. 연기도 잘해서 여운이 오래 남는다!',
#    'is_viewer': '',
#    'author': '윤희주(dbsw****)',
#    'date': '2020-02-21T00:30:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 982,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '괜찮아요 전쟁영화 안좋아하는데~대단한 생명력과 절대 봐주면안된다는 교훈이^^ ㅎㅎ흡입력도 높고 전개도 빠르고~음악도 좋았네요^^ 좀 신선한 전쟁영화였어요!',
#    'is_viewer': '',
#    'author': 'Iopjkl(alvi****)',
#    'date': '2020-02-21T00:13:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 983,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '극장에서 봐야하는 영화다',
#    'is_viewer': '',
#    'author': 'whyitravel(ksu1****)',
#    'date': '2020-02-21T00:04:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 984,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '총질하고 비행기 날아다니는 전쟁영화 별로 안좋아해서 안보는 편인데 2시간 숨도 안쉬고 몰입해서 봄 ㄹㅇ 오랜만에 잘만든 영화본거 같아서 매우 만족스럽다',
#    'is_viewer': '',
#    'author': 'lia(good****)',
#    'date': '2020-02-20T23:44:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 985,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '상상도 하기힘든 롱테이크로 관람객을 전쟁 한복판으로 보내버린다.',
#    'is_viewer': '',
#    'author': 'hbs1****',
#    'date': '2020-02-20T23:32:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 986,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '볼 만한 수작',
#    'is_viewer': '',
#    'author': '절막만지셨자나요(waju****)',
#    'date': '2020-02-20T23:15:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 987,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '이 영화는 꼭 보자.. 그냥 보고 오세요',
#    'is_viewer': '',
#    'author': 'kang****',
#    'date': '2020-02-20T23:02:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 988,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '중간에 장면 전환 없이 계속 영상이 이어져 몰입감이 엄청났다. 전쟁 현장에 함께 있는 느낌. 뻔하지도 않고, 배우들의 연기와 영상미가 합쳐져 더욱 좋은 영화가 탄생할 수 있었다고 생각한다. 재관람하고 싶은 영화......',
#    'is_viewer': '',
#    'author': '소담(sdar****)',
#    'date': '2020-02-20T22:50:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 989,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '이런 영화가 남한에서는 3위랍니다',
#    'is_viewer': '',
#    'author': 'liv(live****)',
#    'date': '2020-02-20T22:46:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 990,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '국내 평론가들 짠듯이 7점으로 도배햇네ㅋㅋㅋ 평론가는 애초에 그럴듯한 사기꾼이라 믿지도 않지만 부끄러운줄 일아라ㅋㅋ 이 영화가 국내 영화라도 7점 도배했을까',
#    'is_viewer': '',
#    'author': 'sky(bmjv****)',
#    'date': '2020-02-20T22:46:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 991,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '명령 수행 중 전장에서 전우를 잃고 사명감과 책임감으로 임무를 수행하는 뻔한 스토리가 이렇게 아름다울 수 있다니. 걷고 뛰고 하는게 거의 전부인 영화인데도 엄청났다... 카메라 워킹도 너무 좋았고 적절하게 울려퍼지는...',
#    'is_viewer': '',
#    'author': '박주희(qkrw****)',
#    'date': '2020-02-20T20:41:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 992,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '1917 그 순간 속에.',
#    'is_viewer': '',
#    'author': '송현우(hyun****)',
#    'date': '2020-02-20T20:35:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 993,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '메롱시티를 처음 본 순간의 충격이다...허걱',
#    'is_viewer': '',
#    'author': 'Sjjahxuasgsuabsffsjq(ku09****)',
#    'date': '2020-02-20T20:33:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 994,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '이 영화 정말 최고인데 집 티비에서 보면 그저그런 영화일듯',
#    'is_viewer': '',
#    'author': 'dlat****',
#    'date': '2020-02-20T19:52:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 995,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '2시간 내내 스코필드와 블레이크 옆 어딘가에 서 있었다...',
#    'is_viewer': '',
#    'author': '인간(tkek****)',
#    'date': '2020-02-20T19:15:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 996,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '두발 뻗고 잘 수 있음에 감사하게 되는 영화입니다영상미 , 음향효과 뭐하나 모자랄 것 없이 완벽했어요',
#    'is_viewer': '',
#    'author': '진화(tkdg****)',
#    'date': '2020-02-20T19:09:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 997,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '군대가기 4일전인데 봤다 눈물나더라',
#    'is_viewer': '',
#    'author': '김성훈(sung****)',
#    'date': '2020-02-20T19:09:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 998,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '진짜... 들숨에 영화 시작해서 날숨에 영화 끝납니다...',
#    'is_viewer': '',
#    'author': 'dlwo****',
#    'date': '2020-02-20T17:01:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 999,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '한참 미래의 촬영기술을 미리 경험하는 듯한',
#    'is_viewer': '',
#    'author': '닮은살걀(yubi****)',
#    'date': '2020-02-20T16:55:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   {'no': 1000,
#    'title': '1917 (1917)',
#    'code': '187321',
#    'score': '10',
#    'comment': '솔직하게 기생충하고 아카데미를 양분했어도 이견이 없을 오래 간만에 등장한 웰메이드 전쟁영화',
#    'is_viewer': '',
#    'author': 'dedap(didl****)',
#    'date': '2020-02-20T16:36:00+09:00',
#    'sympathy': '3',
#    'not_sympathy': '0'},
#   ...]}
