# %%
# !pip3 install git+http://galadriel02.korea.ncsoft.corp/searchtf/pypi/hfmodels.git
# Out:
# Looking in indexes: https://k8s:****@nlp-utils/repository/pypi/simple
# ...
#   Cloning http://galadriel02.korea.ncsoft.corp/searchtf/pypi/hfmodels.git to /tmp/pip-req-build-fv0ifslh
#   Running command git clone -q http://galadriel02.korea.ncsoft.corp/searchtf/pypi/hfmodels.git /tmp/pip-req-build-fv0ifslh
# ...
#   Created wheel for HfModels: filename=HfModels-1.0.0-py3-none-any.whl size=3240 sha256=3dfcc25e8b949d1029cc91d0fe0446434c310c17f49eea879d2b51798ac218b2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8_cgs17x/wheels/1a/47/e1/f6bb321b81b9dc1372ac388d4f8a138fd9a429b45c0e287900
# Successfully built HfModels
# ...

# %%
# !pip3 install transformers torch
# Out:
# Looking in indexes: https://k8s:****@nlp-utils/repository/pypi/simple
# ...
#      |█████████████▏                  | 320.6 MB 121.5 MB/s eta 0:00:04     |██████████▍                     | 252.4 MB 121.5 MB/s eta 0:00:05
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |█████████████████▌              | 424.9 MB 111.7 MB/s eta 0:00:04
#      |█████████████████▊              | 430.9 MB 111.7 MB/s eta 0:00:04
#      |██████████████████              | 436.8 MB 111.7 MB/s eta 0:00:04
#      |██████████████████▎             | 442.7 MB 115.7 MB/s eta 0:00:03
#      |██████████████████▌             | 448.6 MB 115.7 MB/s eta 0:00:03
# ...

# %%
import sys

pkg_info = !pip3 show HfModels
pkg_info = {l.split(':')[0]: l.split(': ')[1]  for l in pkg_info}

sys.path.append(pkg_info['Location'])

pkg_info, sys.path
# Out:
# ({'Name': 'HfModels',
#   'Version': '1.0.0',
#   'Summary': 'huggingface model down and load',
#   'Home-page': 'http://galadriel02.korea.ncsoft.corp/searchtf/pypi/hfmodels',
#   'Author': 'youngjune',
#   'Author-email': 'youngjune@ncsoft.com',
#   'License': 'MIT',
#   'Location': '/home/ejpark/workspace/nlplab/venv/lib/python3.8/site-packages',
#   'Requires': '',
#   'Required-by': ''},
#  ['/home/ejpark/workspace/nlplab/test',
#   '/home/ejpark/workspace/nlplab',
#   '/usr/lib/python38.zip',
#   '/usr/lib/python3.8',
#   '/usr/lib/python3.8/lib-dynload',
#   '',
#   '/home/ejpark/.local/lib/python3.8/site-packages',
#   '/usr/local/lib/python3.8/dist-packages',
#   '/usr/lib/python3/dist-packages',
#   '/usr/lib/python3.8/dist-packages',
#   '/home/ejpark/.local/lib/python3.8/site-packages/IPython/extensions',
#   '/home/ejpark/.ipython',
#   '/home/ejpark/workspace/nlplab/venv/lib/python3.8/site-packages'])

# %%
from HfModels.hf_models import HfModelControl

# %%
hf = HfModelControl()
